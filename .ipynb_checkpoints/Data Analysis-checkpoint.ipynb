# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension()               # pn.extension('tabulator') Switching between extensions might turn plots invisible in the notebook

import holoviews as hv
import hvplot.pandas         # adds hvplot method to pandas objects. Also, sets bokeh as pn extension
from hvplot import hvPlot
import sqlite3

import matplotlib as mpl

mpl.use('agg')                # we are going to use some matplotlib aggregation functions in this project
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# cache data to improve the dashboard performance
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv('dataSets\\allTimeSquads.csv')

    pn.state.cache['data'] = df.copy()

else: 

    df = pn.state.cache['data']

# %%
df.shape
# Out:
# (10964, 12)

# %%
df1930 = df[df.year == 1930]

# %%
df1930
# Out:
#                   player national_team position    birthday  age  caps  \
# 0           Ángel Bossio     Argentina       GK  1905-05-05   25    16
# 1           Juan Botasso     Argentina       GK  1908-10-23   21     2
# 2         Roberto Cherro     Argentina       FW  1907-02-23   23    10
# 3      Alberto Chividini     Argentina       DF  1907-02-23   23     2
# 4        Attilio Demaría     Argentina       FW  1909-03-19   21     0
# ..                   ...           ...      ...         ...  ...   ...
# 236   Ljubiša Stefanović    Yugoslavia       MF  1910-01-04   20     0
# 237     Milan Stojanović    Yugoslavia       GK  1911-12-28   18     0
# 238  Aleksandar Tirnanić    Yugoslavia       FW  1910-07-15   20     5
# 239       Dragomir Tošić    Yugoslavia       DF  1909-11-08   20     0
# 240    Đorđe Vujadinović    Yugoslavia       FW  1909-11-29   20     4
#
#                     club            club_origin     wc_date  year  \
# 0          Talleres (BA)              Argentina  1930-07-17  1930
# 1          Argentino (Q)              Argentina  1930-07-17  1930
# 2           Boca Juniors              Argentina  1930-07-17  1930
# 3          Central Norte              Argentina  1930-07-17  1930
# 4    Estudiantil Porteño              Argentina  1930-07-17  1930
# ..                   ...                    ...         ...   ...
# 236              FC Sète                 France  1930-07-17  1930
# 237          BSK Beograd  Kingdom of Yugoslavia  1930-07-17  1930
# 238          BSK Beograd  Kingdom of Yugoslavia  1930-07-17  1930
# 239          BSK Beograd  Kingdom of Yugoslavia  1930-07-17  1930
# 240          BSK Beograd  Kingdom of Yugoslavia  1930-07-17  1930
#
#      confederation imputed
# 0    South America       -
# 1    South America       -
# 2    South America       -
# 3    South America       -
# 4    South America       -
# ..             ...     ...
# 236         Europe       -
# 237         Europe       -
# 238         Europe       -
# 239         Europe       -
# 240         Europe       -
#
# [241 rows x 12 columns]

# %%
df.head()
# Out:
#               player national_team position    birthday  age  caps  \
# 0       Ángel Bossio     Argentina       GK  1905-05-05   25    16
# 1       Juan Botasso     Argentina       GK  1908-10-23   21     2
# 2     Roberto Cherro     Argentina       FW  1907-02-23   23    10
# 3  Alberto Chividini     Argentina       DF  1907-02-23   23     2
# 4    Attilio Demaría     Argentina       FW  1909-03-19   21     0
#
#                   club club_origin     wc_date  year  confederation imputed
# 0        Talleres (BA)   Argentina  1930-07-17  1930  South America       -
# 1        Argentino (Q)   Argentina  1930-07-17  1930  South America       -
# 2         Boca Juniors   Argentina  1930-07-17  1930  South America       -
# 3        Central Norte   Argentina  1930-07-17  1930  South America       -
# 4  Estudiantil Porteño   Argentina  1930-07-17  1930  South America       -

# %%
df = df.drop(columns = 'birthday')

# %%
wc = df[df.year == 1930]

# %%
wc.age.mean()
# Out:
# 24.443983402489625

# %%
wc2 = df[df.year == 2022]

# %%
wc2.age.mean()
# Out:
# 26.94344163658243

# %%
wc3 = df[df.year == 2018]

# %%
wc3.age
# Out:
# 9397     32
# 9398     31
# 9399     25
# 9400     31
# 9401     32
#          ..
# 10128    27
# 10129    28
# 10130    31
# 10131    31
# 10132    35
# Name: age, Length: 736, dtype: int64

# %%
df.year.unique()
# Out:
# array([1930, 1934, 1938, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978,
#        1982, 1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018, 2022],
#       dtype=int64)

# %%
# Calculate the average age of players for each world cup

# %%
for y in df.year.unique():
    means = df[df.year == y].age.mean()
    means = round(means,2)
    print(means)
# Out:
# 24.44
# 24.92
# 25.43
# 26.46
# 26.38
# 26.27
# 25.78
# 25.79
# 25.76
# 26.21
# 26.1
# 26.61
# 26.63
# 26.39
# 26.85
# 27.01
# 26.97
# 26.88
# 26.9
# 26.85
# 27.44
# 26.94

# %%
groupYear = df.groupby(['year'])

# %%
#countAge = groupYear['age'].value_counts().to_frame().rename(columns = {'age':'count'}).reset_index(1)

# %%
countAge = groupYear['age'].mean()
countAge = round(countAge,2)
countAge.to_frame().reset_index()
# Out:
#     year    age
# 0   1930  24.44
# 1   1934  24.92
# 2   1938  25.43
# 3   1950  26.46
# 4   1954  26.38
# 5   1958  26.27
# 6   1962  25.78
# 7   1966  25.79
# 8   1970  25.76
# 9   1974  26.21
# 10  1978  26.10
# 11  1982  26.61
# 12  1986  26.63
# 13  1990  26.39
# 14  1994  26.85
# 15  1998  27.01
# 16  2002  26.97
# 17  2006  26.88
# 18  2010  26.90
# 19  2014  26.85
# 20  2018  27.44
# 21  2022  26.94

# %%
# calculate median age of players

# %%
print("Medians")
for y in df.year.unique():
    medians = df[df.year == y].age.median()
    print(f"{y} = {medians} years old")
# Out:
# Medians
# 1930 = 24.0 years old
# 1934 = 25.0 years old
# 1938 = 25.0 years old
# 1950 = 27.0 years old
# 1954 = 26.0 years old
# 1958 = 26.0 years old
# 1962 = 25.0 years old
# 1966 = 25.0 years old
# 1970 = 26.0 years old
# 1974 = 26.0 years old
# 1978 = 26.0 years old
# 1982 = 26.0 years old
# 1986 = 26.0 years old
# 1990 = 26.0 years old
# 1994 = 27.0 years old
# 1998 = 27.0 years old
# 2002 = 27.0 years old
# 2006 = 27.0 years old
# 2010 = 27.0 years old
# 2014 = 27.0 years old
# 2018 = 27.0 years old
# 2022 = 27.0 years old

# %%
#hvplot.help('bar')

# %%
def plot_world_avg_exp(year): # receives a slider object.
    year_df = df[df['year'] == year]
    
    return year_df.hvplot.bar('year', y='caps',   # y default is = all numeric columns
                              height=320, width=550,line_color = 'black', color = 'purple',ylim=(0,50),
                              legend=False, yformatter='%.0f'
                              
                             ).aggregate(function=np.mean).opts(xlabel="Year", ylabel="Avg. caps",
                                                                title="Iternational experience (world)",xrotation=20)

# %%
def plot_sa_avg_exp(year): # receives a slider object.

    year_df = df[(df['year'] == year) & (df['confederation']== 'South America')]
    
    return year_df.hvplot.bar('year', y='caps',   # y default is = all numeric columns
                              height=320, width=550,line_color = 'black', color = 'purple',ylim=(0,50),
                              legend=False, yformatter='%.0f'
                              
                             ).aggregate(function=np.mean).opts(xlabel="Year", ylabel="Avg. caps",
                                                                title="Iternational experience (south america)",xrotation=20)

# %%
# Create a slider widget 
year_slider2 = pn.widgets.IntSlider(name='Year Slider', width=200,
                                 start=1930, end=2022, value=(1930),
                                 step=4,value_throttled=(1930))
# Apply a callback policy                                 
@pn.depends(year_slider2.param.value_throttled)
def year_selected(year_slider2):
    return '### Jobs in {}'.format(year_slider2)

# %%
year_slider2
# Out:
# IntSlider(end=2022, name='Year Slider', start=1930, step=4, value=1930, width=200)

# %%
plots_box2 = pn.WidgetBox(pn.Row(pn.bind(plot_world_avg_exp,year_slider2), align="start", sizing_mode="stretch_width"))

# %%
plots_box2
# Out:
# WidgetBox
#     [0] Row(sizing_mode='stretch_width')
#         [0] ParamFunction(function)

# %%
df
# Out:
#                   player national_team position  age  caps  \
# 0           Ángel Bossio     Argentina       GK   25    16
# 1           Juan Botasso     Argentina       GK   21     2
# 2         Roberto Cherro     Argentina       FW   23    10
# 3      Alberto Chividini     Argentina       DF   23     2
# 4        Attilio Demaría     Argentina       FW   21     0
# ...                  ...           ...      ...  ...   ...
# 10959       Sorba Thomas         Wales       MF   23     6
# 10960       Dylan Levitt         Wales       MF   22    13
# 10961        Ben Cabango         Wales       DF   22     5
# 10962      Rubin Colwill         Wales       MF   20     7
# 10963      Matthew Smith         Wales       MF   23    19
#
#                       club club_origin     wc_date  year  confederation  \
# 0            Talleres (BA)   Argentina  1930-07-17  1930  South America
# 1            Argentino (Q)   Argentina  1930-07-17  1930  South America
# 2             Boca Juniors   Argentina  1930-07-17  1930  South America
# 3            Central Norte   Argentina  1930-07-17  1930  South America
# 4      Estudiantil Porteño   Argentina  1930-07-17  1930  South America
# ...                    ...         ...         ...   ...            ...
# 10959    Huddersfield Town     England  2022-11-20  2022         Europe
# 10960        Dundee United    Scotland  2022-11-20  2022         Europe
# 10961         Swansea City       Wales  2022-11-20  2022         Europe
# 10962         Cardiff City       Wales  2022-11-20  2022         Europe
# 10963   Milton Keynes Dons     England  2022-11-20  2022         Europe
#
#       imputed
# 0           -
# 1           -
# 2           -
# 3           -
# 4           -
# ...       ...
# 10959       -
# 10960       -
# 10961       -
# 10962       -
# 10963       -
#
# [10964 rows x 11 columns]

# %%
df.hvplot.line(x= 'year' , y= ['age']).aggregate(function=np.mean)
# Out:
# :Curve   [year]   (age)

# %% [markdown]
# ### Average international player experience, by world cup

# %%
df.hvplot.line(x= 'year' , y= ['caps']).aggregate(function=np.mean)
# Out:
# :Curve   [year]   (caps)

# %%
conts = df.groupby(['year','confederation'])['caps'].mean()

# %%
conts = conts.to_frame().reset_index()
conts
# Out:
#      year  confederation       caps
# 0    1930         Europe   6.406250
# 1    1930  North America   0.727273
# 2    1930  South America   4.270833
# 3    1934         Africa   1.650000
# 4    1934         Europe   9.787072
# ..    ...            ...        ...
# 99   2022           Asia  39.038760
# 100  2022         Europe  35.872781
# 101  2022  North America  38.240385
# 102  2022        Oceania  20.653846
# 103  2022  South America  35.125000
#
# [104 rows x 3 columns]

# %%
sorted_conts = conts.sort_values(by=['confederation', 'year']).reset_index(drop = True)

# %%
sorted_conts.iloc[100:106]
# Out:
#      year  confederation       caps
# 100  2010  South America  28.860870
# 101  2014  South America  35.072464
# 102  2018  South America  35.269565
# 103  2022  South America  35.125000

# %% [markdown]
# ## Países con más presencias

# %%
nations = df[['year','national_team']]

# %%
naciones= nations.groupby(['year','national_team'])['national_team'].count().reset_index(name='jugadores')

# %%
naciones
# Out:
#      year  national_team  jugadores
# 0    1930      Argentina         22
# 1    1930        Belgium         16
# 2    1930        Bolivia         17
# 3    1930         Brazil         22
# 4    1930          Chile         19
# ..    ...            ...        ...
# 484  2022    Switzerland         26
# 485  2022        Tunisia         26
# 486  2022  United States         26
# 487  2022        Uruguay         26
# 488  2022          Wales         26
#
# [489 rows x 3 columns]

# %%
# Encontrar el valor mínimo en la columna 'count'
min_count = naciones['jugadores'].min()

# %%
# Crear una máscara booleana para identificar las filas con el valor mínimo
min_players = naciones[naciones['jugadores'] == min_count]

# %%
min_players
# Out:
#     year national_team  jugadores
# 9   1930       Romania         15
# 31  1938          Cuba         15

# %%
naciones.drop('jugadores',axis=1)
# Out:
#      year  national_team
# 0    1930      Argentina
# 1    1930        Belgium
# 2    1930        Bolivia
# 3    1930         Brazil
# 4    1930          Chile
# ..    ...            ...
# 484  2022    Switzerland
# 485  2022        Tunisia
# 486  2022  United States
# 487  2022        Uruguay
# 488  2022          Wales
#
# [489 rows x 2 columns]

# %%
naciones.national_team.value_counts().iloc[0:50]
# Out:
# Brazil            22
# Argentina         18
# Italy             18
# Mexico            17
# France            16
# England           16
# Spain             16
# Belgium           14
# Uruguay           14
# Switzerland       12
# Sweden            12
# South Korea       11
# Netherlands       11
# United States     11
# West Germany      10
# Germany           10
# Hungary            9
# Yugoslavia         9
# Chile              9
# Poland             9
# Czechoslovakia     8
# Cameroon           8
# Portugal           8
# Scotland           8
# Paraguay           8
# Austria            7
# Soviet Union       7
# Romania            7
# Japan              7
# Bulgaria           7
# Iran               6
# Tunisia            6
# Denmark            6
# Costa Rica         6
# Nigeria            6
# Croatia            6
# Saudi Arabia       6
# Morocco            6
# Australia          6
# Colombia           6
# Peru               5
# Algeria            4
# Ecuador            4
# Russia             4
# Ghana              4
# Norway             3
# Bolivia            3
# South Africa       3
# Honduras           3
# Egypt              3
# Name: national_team, dtype: int64

# %%
Germany = naciones.national_team.value_counts().iloc[14:16].sum()

# %%
Germany
# Out:
# 20

# %% [markdown]
# ## Clubes que más jugadores aportaron

# %%
df
# Out:
#                   player national_team position  age  caps  \
# 0           Ángel Bossio     Argentina       GK   25    16
# 1           Juan Botasso     Argentina       GK   21     2
# 2         Roberto Cherro     Argentina       FW   23    10
# 3      Alberto Chividini     Argentina       DF   23     2
# 4        Attilio Demaría     Argentina       FW   21     0
# ...                  ...           ...      ...  ...   ...
# 10959       Sorba Thomas         Wales       MF   23     6
# 10960       Dylan Levitt         Wales       MF   22    13
# 10961        Ben Cabango         Wales       DF   22     5
# 10962      Rubin Colwill         Wales       MF   20     7
# 10963      Matthew Smith         Wales       MF   23    19
#
#                       club club_origin     wc_date  year  confederation  \
# 0            Talleres (BA)   Argentina  1930-07-17  1930  South America
# 1            Argentino (Q)   Argentina  1930-07-17  1930  South America
# 2             Boca Juniors   Argentina  1930-07-17  1930  South America
# 3            Central Norte   Argentina  1930-07-17  1930  South America
# 4      Estudiantil Porteño   Argentina  1930-07-17  1930  South America
# ...                    ...         ...         ...   ...            ...
# 10959    Huddersfield Town     England  2022-11-20  2022         Europe
# 10960        Dundee United    Scotland  2022-11-20  2022         Europe
# 10961         Swansea City       Wales  2022-11-20  2022         Europe
# 10962         Cardiff City       Wales  2022-11-20  2022         Europe
# 10963   Milton Keynes Dons     England  2022-11-20  2022         Europe
#
#       imputed
# 0           -
# 1           -
# 2           -
# 3           -
# 4           -
# ...       ...
# 10959       -
# 10960       -
# 10961       -
# 10962       -
# 10963       -
#
# [10964 rows x 11 columns]

# %% [markdown]
# ## Normalizar nombres de países, para no tener datos divididos

# %%
df.club_origin.unique()
# Out:
# array(['Argentina', 'Belgium', 'Bolivia', 'Brazil', 'Chile', 'France',
#        'Mexico', 'Paraguay', 'Peru', 'Romania', 'United States',
#        'Uruguay', 'Kingdom of Yugoslavia', 'Austria', 'Czechoslovakia',
#        'Egypt', 'Germany', 'Hungary', 'Italy', 'Netherlands', 'Spain',
#        'Sweden', 'Switzerland', 'Cuba', 'Dutch East Indies', 'Norway',
#        'Poland', 'England', 'Socialist Federal Republic of Yugoslavia',
#        'Scotland', 'South Korea', 'Turkey', 'West Germany',
#        'Northern Ireland', 'Soviet Union', 'Wales', 'Bulgaria',
#        'Colombia', 'North Korea', 'Portugal', 'El Salvador', 'Israel',
#        'Morocco', 'Australia', 'East Germany', 'Haiti',
#        'Trinidad and Tobago', 'Zaire', '-', 'Iran', 'Tunisia',
#        'Saudi Arabia', 'Algeria', 'Cameroon', 'Ivory Coast', 'Guatemala',
#        'Honduras', 'Kuwait', 'New Zealand', 'Canada', 'Denmark', 'Greece',
#        'Iraq', 'Réunion', 'Costa Rica', 'United Arab Emirates', 'Japan',
#        'Qatar', 'Russia', 'Ecuador', 'Croatia',
#        'Federal Republic of Yugoslavia', 'Jamaica', 'South Africa',
#        'China', 'Ukraine', 'Nigeria', 'Senegal', 'Slovenia',
#        'Czech Republic', 'Angola', 'Ghana', 'Serbia', 'Mali', 'Cyprus',
#        'Togo', 'Slovakia', 'Bosnia and Herzegovina', 'Finland', 'Iceland',
#        'Panama', 'Guinea'], dtype=object)

# %%
# Utiliza el método .replace() con un diccionario para realizar las sustituciones
df['club_origin'] = df['club_origin'].replace({'Kingdom of Yugoslavia': 'Yugoslavia',
                                     'Socialist Federal Republic of Yugoslavia': 'Yugoslavia',
                                     'Federal Republic of Yugoslavia': 'Yugoslavia',
                                     'East Germany': 'Germany',
                                     'West Germany': 'Germany'})

# %%
naciones= nations.groupby(['year','national_team'])['national_team'].count().reset_index(name='jugadores')

# %%
origen_club=df.club_origin.unique().tolist()

# %%
#sorted(origen_club)

# %%
dash = '-'

# %%
coincidencias = df['club_origin'] == dash

# %%
filas = df[coincidencias]

# %%
filas
# Out:
#                  player national_team position  age  caps        club  \
# 3303  Alberto Tarantini     Argentina       DF   22    26  Free Agent
#
#      club_origin     wc_date  year  confederation imputed
# 3303           -  1978-06-01  1978  South America       -

# %%
df['club_and_origin'] = df['club'] + ' from ' + df['club_origin']

# %%
clubs = df['club_and_origin'].to_frame()

# %%
clubs
# Out:
#                           club_and_origin
# 0            Talleres (BA) from Argentina
# 1            Argentino (Q) from Argentina
# 2             Boca Juniors from Argentina
# 3            Central Norte from Argentina
# 4      Estudiantil Porteño from Argentina
# ...                                   ...
# 10959      Huddersfield Town from England
# 10960         Dundee United from Scotland
# 10961             Swansea City from Wales
# 10962             Cardiff City from Wales
# 10963     Milton Keynes Dons from England
#
# [10964 rows x 1 columns]

# %%
clubs_or = clubs.club_and_origin.unique().tolist()

# %%
sorted(clubs_or)
# Out:
# ['1. FC Kaiserslautern from Germany',
#  '1. FC Kaiserslautern[8] from Germany',
#  '1. FC Köln from Germany',
#  '1. FC Köln[7] from Germany',
#  '1. FC Lokomotive Leipzig from Germany',
#  '1. FC Magdeburg from Germany',
#  '1. FC Nürnberg from Germany',
#  '1. FC Nürnberg[105] from Germany',
#  '1. FC Saarbrücken from Germany',
#  '1. FC Schweinfurt 05 from Germany',
#  '1. Simmeringer SC from Austria',
#  '1860 Munich from Germany',
#  '1899 Hoffenheim from Germany',
#  '1899 Hoffenheim[141] from Germany',
#  '8 August from North Korea',
#  '8 February from North Korea',
#  'A.C. Mantova from Italy',
#  'A.S.V. Oostende K.M. from Belgium',
#  'AC Bellinzona from Switzerland',
#  'AC Sparta Prague from Czechoslovakia',
#  'ADO Den Haag from Netherlands',
#  'AEK Athens F.C. from Greece',
#  'AEK Athens from Greece',
#  'AFC Bournemouth from England',
#  'AFC Wimbledon from England',
#  'AGF from Denmark',
#  'AIK from Sweden',
#  'AKS Chorzów from Poland',
#  'AMEF Arad from Romania',
#  'APIA Leichhardt from Australia',
#  'APOEL from Cyprus',
#  'AS Bilima from Zaire',
#  'AS Marsa from Tunisia',
#  'AS Monaco from France',
#  'AS Saint-Étienne from France',
#  'AS Sale from Morocco',
#  'AS Troyes from France',
#  'AS Vita Club from Zaire',
#  'ASA from Angola',
#  "ASC Jeanne d'Arc from Senegal",
#  'ASEC Mimosas from Ivory Coast',
#  'ASO Chlef from Algeria',
#  'AZ from Netherlands',
#  'AaB from Denmark',
#  'Aalesund from Norway',
#  'Aarau from Switzerland',
#  'Aberdeen from Scotland',
#  'Abha from Saudi Arabia',
#  'Abu Moslem from Iran',
#  'Académica de Coimbra from Portugal',
#  'Adalet SK Istanbul from Turkey',
#  'Adelaide City from Australia',
#  'Adelaide United from Australia',
#  'Adler San Nicolas from El Salvador',
#  'Admira Wacker from Austria',
#  'Admira Wacker[79] from Austria',
#  'Admira Wien from Austria',
#  'Admira Wien[F] from Germany',
#  'Admira/Wacker from Austria',
#  'Aduana Stars from Ghana',
#  'Africa Sports from Ivory Coast',
#  'Aigle Noir from Haiti',
#  'Airdrieonians from Scotland',
#  'Ajaccio from France',
#  'Ajaccio[31] from France',
#  'Ajax Amsterdam from Netherlands',
#  'Ajax Cape Town from South Africa',
#  'Ajax from Netherlands',
#  'Ajax[46] from Netherlands',
#  'Akademik Sofia from Bulgaria',
#  'Akademisk from Denmark',
#  'Akhmat Grozny from Russia',
#  'Al Ahli from Saudi Arabia',
#  'Al Ahly from Egypt',
#  'Al Ain from United Arab Emirates',
#  'Al Batin from Saudi Arabia',
#  'Al Ettifaq from Saudi Arabia',
#  'Al Fateh from Saudi Arabia',
#  'Al Hilal from Saudi Arabia',
#  'Al Hilal[80] from Saudi Arabia',
#  'Al Jazira from United Arab Emirates',
#  'Al Khaleej Club from United Arab Emirates',
#  'Al Nassr from Saudi Arabia',
#  'Al Qadsiah from Saudi Arabia',
#  'Al Raed from Saudi Arabia',
#  'Al Sadd from Qatar',
#  'Al Shaab from United Arab Emirates',
#  'Al Shabab from Saudi Arabia',
#  'Al Shabab from United Arab Emirates',
#  'Al Taawoun from Saudi Arabia',
#  'Al Tadamun from Kuwait',
#  'Al-Ahli Doha from Qatar',
#  'Al-Ahli from Saudi Arabia',
#  'Al-Ahli from United Arab Emirates',
#  'Al-Arabi from Kuwait',
#  'Al-Arabi from Qatar',
#  'Al-Duhail from Qatar',
#  'Al-Ettifaq from Saudi Arabia',
#  'Al-Fateh from Saudi Arabia',
#  'Al-Gharafa from Qatar',
#  'Al-Hilal from Saudi Arabia',
#  'Al-Ittihad from Egypt',
#  'Al-Ittihad from Saudi Arabia',
#  'Al-Jaish from Iraq',
#  'Al-Khaleej from Saudi Arabia',
#  'Al-Kuwait from Kuwait',
#  'Al-Masry AC Port Said from Egypt',
#  'Al-Masry from Egypt',
#  'Al-Nasr from United Arab Emirates',
#  'Al-Nassr from Saudi Arabia',
#  'Al-Olympi Alexandria from Egypt',
#  'Al-Qadsia from Kuwait',
#  'Al-Rasheed from Iraq',
#  'Al-Rayyan from Qatar',
#  'Al-Rayyan[9] from Qatar',
#  'Al-Riyadh from Saudi Arabia',
#  'Al-Sadd from Qatar',
#  'Al-Salmiya from Kuwait',
#  'Al-Shabab from Iraq',
#  'Al-Shabab from Saudi Arabia',
#  'Al-Sharjah[36] from United Arab Emirates',
#  'Al-Shorta from Iraq',
#  'Al-Siliyah from Qatar',
#  "Al-Ta'ee from Saudi Arabia",
#  'Al-Tai from Saudi Arabia',
#  'Al-Talaba from Iraq',
#  'Al-Tayaran from Iraq',
#  'Al-Wakrah from Qatar',
#  'Al-Wakrah[34] from Qatar',
#  'Al-Wasl from United Arab Emirates',
#  'Al-Wehda from Saudi Arabia',
#  'Alajuelense from Costa Rica',
#  'Alania Vladikavkaz from Russia',
#  'Alanyaspor from Turkey',
#  'Alavés from Spain',
#  'Albany Capitals from United States',
#  'Albirex Niigata from Japan',
#  'Alemannia Aachen from Germany',
#  'Alianza Lima from Peru',
#  'Alianza Oruro from Bolivia',
#  'Alianza from El Salvador',
#  'Almagro from Argentina',
#  'Almería from Spain',
#  'Ambrosiana-Inter from Italy',
#  'America-RJ from Brazil',
#  'Americano-RJ from Brazil',
#  'Americano-RS from Brazil',
#  'Amiens AC from France',
#  'Amiens from France',
#  'Amkar Perm from Russia',
#  'Amkar Perm[150] from Russia',
#  'Amrokgang from North Korea',
#  'América de Cali from Colombia',
#  'América from Mexico',
#  'América[28] from Mexico',
#  'América[39] from Mexico',
#  'Ancona from Italy',
#  'Anderlecht from Belgium',
#  'Anderlecht[12] from Belgium',
#  'Angers from France',
#  'Ankaragücü from Turkey',
#  'Ankaraspor from Turkey',
#  'Antalyaspor from Turkey',
#  'Antwerp from Belgium',
#  'Anyang LG Cheetahs from South Korea',
#  'Anzhi Makhachkala[152] from Russia',
#  'Apollon Smyrnis from Greece',
#  'April 25 from North Korea',
#  'Ararat Yerevan from Soviet Union',
#  'Archibald from Trinidad and Tobago',
#  'Argentino (Q) from Argentina',
#  'Argentinos Juniors from Argentina',
#  'Argeș Pitești from Romania',
#  'Aris from Greece',
#  'Arka Gdynia from Poland',
#  'Arles-Avignon from France',
#  'Arminia Bielefeld from Germany',
#  'Arnett Gardens from Jamaica',
#  'Arsenal F.C. from England',
#  'Arsenal Tula from Russia',
#  'Arsenal from England',
#  'Arsenal[91] from England',
#  'Arturo Fernández Vial from Chile',
#  'Asan Mugunghwa from South Korea',
#  'Asante Kotoko from Ghana',
#  'Ashanti Gold from Ghana',
#  'Ashdod from Israel',
#  'Aston Villa from England',
#  'Asturias from Mexico',
#  'Atalanta from Italy',
#  'Athletic Bilbao from Spain',
#  'Athletico Paranaense from Brazil',
#  'Atlanta United FC from United States',
#  'Atlante F.C. from Mexico',
#  'Atlante San Alejo from El Salvador',
#  'Atlante from Mexico',
#  'Atlas from Mexico',
#  'Atlético Bilbao from Spain',
#  'Atlético Bucaramanga from Colombia',
#  'Atlético Chalaco from Peru',
#  'Atlético Español from Mexico',
#  'Atlético Junior from Colombia',
#  'Atlético Madrid from Spain',
#  'Atlético Madrid[146] from Spain',
#  'Atlético Madrid[48] from Spain',
#  'Atlético Marte from El Salvador',
#  'Atlético Mineiro from Brazil',
#  'Atlético Nacional from Colombia',
#  'Atlético Paranaense from Brazil',
#  'Atlético de Bilbao from Spain',
#  'Atromitos from Greece',
#  'Aucas from Ecuador',
#  'Auckland City from New Zealand',
#  'Audax Italiano from Chile',
#  'Austria Salzburg from Austria',
#  'Austria Vienna from Austria',
#  'Austria Wien from Austria',
#  'Austria Wien[47] from Austria',
#  'Auxerre from France',
#  'Avellino from Italy',
#  'BC Augsburg from Germany',
#  'BFC Dynamo from Germany',
#  'BSG Sachsenring Zwickau from Germany',
#  'BSK Beograd from Yugoslavia',
#  'BV Borussia Dortmund from Germany',
#  'Bahman from Iran',
#  'Baltimore Blast from United States',
#  'Baltimore Canton from United States',
#  'Banatul Timișoara from Romania',
#  'Banfield from Argentina',
#  'Bangu from Brazil',
#  'Baník Handlová from Czechoslovakia',
#  'Baník Kladno from Czechoslovakia',
#  'Baník Ostrava from Czechoslovakia',
#  'Barcelona SC from Ecuador',
#  'Barcelona from Ecuador',
#  'Barcelona from Spain',
#  'Barcelona[20] from Spain',
#  'Barcelona[27] from Spain',
#  'Barcelona[42] from Spain',
#  'Barcelona[49] from Spain',
#  'Bargh Shiraz from Iran',
#  'Bari from Italy',
#  'Barracas Central from Argentina',
#  'Barreirense from Portugal',
#  'Basel from Switzerland',
#  'Basel[102] from Switzerland',
#  'Basel[103] from Switzerland',
#  'Basel[76] from Switzerland',
#  'Bastia from France',
#  'Bastia[83] from France',
#  'Bayer Leverkusen from Germany',
#  'Bayer Leverkusen[10] from Germany',
#  'Bayer Leverkusen[33] from Germany',
#  'Bayer Uerdingen from Germany',
#  'Bayern Munich from Germany',
#  'Bayern Munich[24] from Germany',
#  'Bayern Munich[62] from Germany',
#  'Bayern Munich[6] from Germany',
#  'Be Quick 1887 from Netherlands',
#  'Bechem Chelsea from Ghana',
#  'Beerschot from Belgium',
#  "Beijing Guo'an from China",
#  'Beijing Guoan from China',
#  'Beijing Sinobo Guoan from China',
#  'Beira-Mar from Portugal',
#  'Belenenses from Portugal',
#  'Bella Vista from Uruguay',
#  'Bellmare Hiratsuka from Japan',
#  'Ben Millers from United States',
#  'Benevento from Italy',
#  'Benfica from Portugal',
#  'Benfica[110] from Portugal',
#  'Berchem Sport from Belgium',
#  'Bern from Switzerland',
#  'Beroe Stara Zagora from Bulgaria',
#  'Besançon from France',
#  'Beveren from Belgium',
#  'Beşiktaş J.K. from Turkey',
#  'Beşiktaş from Turkey',
#  'Beşiktaş[11] from Turkey',
#  'Bienne-Biel from Switzerland',
#  'Birmingham City from England',
#  'Birmingham City[58] from England',
#  'Bizertin from Tunisia',
#  'Blackburn Rovers F.C. from England',
#  'Blackburn Rovers from England',
#  'Blackpool F.C. from England',
#  'Blackpool from England',
#  'Bloemfontein Celtic from South Africa',
#  'Blooming from Bolivia',
#  'Bnei Yehuda from Israel',
#  'Boavista from Portugal',
#  'Boca Juniors Antofagasta from Chile',
#  'Boca Juniors from Argentina',
#  'Boca Juniors[26] from Argentina',
#  'Bohemians Praha from Czechoslovakia',
#  'Bolivar from Bolivia',
#  'Bologna from Italy',
#  'Bolton Wanderers from England',
#  'Bolton Wanderers[40] from England',
#  'Bolívar from Bolivia',
#  'Borac Banja Luka from Bosnia and Herzegovina',
#  'Bordeaux from France',
#  'Borussia Dortmund from Germany',
#  'Borussia Dortmund[48] from Germany',
#  'Borussia Dortmund[49] from Germany',
#  'Borussia Mönchengladbach from Germany',
#  'Botafogo from Brazil',
#  'Botev Plovdiv from Bulgaria',
#  'Botev Vratsa from Bulgaria',
#  'Bournemouth from England',
#  'Bradford City from England',
#  'Braga from Portugal',
#  'Braga[138] from Portugal',
#  'Brașov from Romania',
#  'Brentford from England',
#  'Brescia from Italy',
#  'Brest from France',
#  'Brighton & Hove Albion from England',
#  'Brisbane Roar from Australia',
#  'Bristol City from England',
#  'Brookhattan from United States',
#  'Brooklyn Celtic from United States',
#  'Brooklyn Hispano from United States',
#  'Brujas from Costa Rica',
#  'Brøndby from Denmark',
#  'Brøndby[23] from Denmark',
#  'Brønshøj from Denmark',
#  'Bucheon SK from South Korea',
#  'Budapest Honvéd FC from Hungary',
#  'Budapest Honvéd from Hungary',
#  'Budapesti Dózsa from Hungary',
#  'Budapesti Honvéd SE from Hungary',
#  'Budapesti Kinizsi from Hungary',
#  'Budapesti Vasas SE from Hungary',
#  'Budapesti Vörös Lobogó from Hungary',
#  'Budućnost Titograd from Yugoslavia',
#  'Burnley F.C. from England',
#  'Burnley from England',
#  'Bursaspor from Turkey',
#  'Bury from England',
#  'Busan Daewoo Royals from South Korea',
#  "Busan I'Cons from South Korea",
#  'Busan IPark from South Korea',
#  'Békéscsabai Előre from Hungary',
#  'CA Bizertin from Tunisia',
#  'CA Paris from France',
#  'CA Timișoara from Romania',
#  'CAO Oradea from Romania',
#  'CASG Paris from France',
#  'CD Chalatenango from El Salvador',
#  'CD Cuautla from Mexico',
#  'CD Guadalajara from Mexico',
#  'CD Guadalajara[1] from Mexico',
#  'CD Ingavi from Bolivia',
#  'CD Marte from Mexico',
#  'CD Olimpia from Honduras',
#  'CD Oro from Mexico',
#  'CD Real Sociedad from Honduras',
#  'CD Santiago from Chile',
#  'CD Tampico from Mexico',
#  'CD Zacatepec from Mexico',
#  'CDNA Sofia from Bulgaria',
#  'CF Atlas from Mexico',
#  'CF Barcelona from Spain',
#  'CF Monterrey from Mexico',
#  'CF Montréal from Canada',
#  'CH Bratislava from Czechoslovakia',
#  'CKD Praha from Czechoslovakia',
#  'CM Belcourt from Algeria',
#  'CODM Meknes from Morocco',
#  'COT Tunis from Tunisia',
#  'CS Constantine from Algeria',
#  'CS Imana from Zaire',
#  'CS Sfaxien from Tunisia',
#  'CSKA Moscow from Russia',
#  'CSKA Moscow from Soviet Union',
#  'CSKA SZ Sofia from Bulgaria',
#  'CSKA Sofia from Bulgaria',
#  'Caen from France',
#  'Cagliari from Italy',
#  'Cairo Shourta Police from Egypt',
#  'Calavera La Paz from Bolivia',
#  'Calcio Catania from Italy',
#  'Cambridge United from England',
#  'Cannes from France',
#  'Canon Yaounde from Cameroon',
#  'Canon Yaoundé from Cameroon',
#  'Canterbury United from New Zealand',
#  'Cantonal Neuchâtel from Switzerland',
#  'Cape Town Spurs from South Africa',
#  'Cardiff City from Wales',
#  'Cartaginés from Costa Rica',
#  'Catania from Italy',
#  'Catania[111] from Italy',
#  'Celta Vigo from Spain',
#  'Celtic from Scotland',
#  'Celtic[58] from Scotland',
#  'Central Coast Mariners from Australia',
#  'Central Coast Mariners[59] from Australia',
#  'Central Norte from Argentina',
#  'Central from Uruguay',
#  'Centro Gallego from Cuba',
#  'Cercle Brugge from Belgium',
#  'Cerezo Osaka from Japan',
#  'Cerro Corá from Paraguay',
#  'Cerro Porteño from Paraguay',
#  'Cerro from Uruguay',
#  'Cesena from Italy',
#  'Chabab Mohammedia from Morocco',
#  'Chabab Mohammédia from Morocco',
#  'Changchun Yatai from China',
#  'Charleroi SC from Belgium',
#  'Charleroi from Belgium',
#  'Charlotte FC from United States',
#  'Charlton Athletic from England',
#  'Chaves from Portugal',
#  'Chelsea from England',
#  'Chelsea[12] from England',
#  'Chelsea[14] from England',
#  'Chelsea[71] from England',
#  'Chelsea[7] from England',
#  'Cheonan Ilhwa Chunma from South Korea',
#  'Cherno More Varna from Bulgaria',
#  'Chesterfield from England',
#  'Chiapas from Mexico',
#  'Chicago Eagles from United States',
#  'Chicago Fire FC from United States',
#  'Chicago Fire from United States',
#  'Chicago Slovak from United States',
#  'Chicago Sting from United States',
#  'Chicago Vikings from United States',
#  'Chicago Wonderbolts from United States',
#  'Chievo from Italy',
#  'Chinezul Timișoara from Romania',
#  'Chippa United from South Africa',
#  'Chivas USA from United States',
#  'Chornomorets Odesa from Soviet Union',
#  'Chorrillo from Panama',
#  'Chosun Textile Company FC from South Korea',
#  'Chosun University from South Korea',
#  'Châteauroux from France',
#  'Chênois from Switzerland',
#  'Ciudad de Murcia from Spain',
#  'Clermont from France',
#  'Cleveland Force from United States',
#  'Cleveland Slavia from United States',
#  'Club Africain from Tunisia',
#  'Club América from Mexico',
#  'Club Atletico Estudiantil Porteño from Argentina',
#  'Club Atlético Estudiantil Porteño from Argentina',
#  'Club Bolivar from Bolivia',
#  'Club Bolívar from Bolivia',
#  'Club Brugge from Belgium',
#  'Club Deportivo Marte from Mexico',
#  'Club Français from France',
#  'Club Irapuato from Mexico',
#  'Club Jorge Wilstermann from Bolivia',
#  'Club León from Mexico',
#  'Club Libertad from Paraguay',
#  'Club Litoral from Bolivia',
#  'Club San José from Bolivia',
#  'Club Sportivo Alsina from Argentina',
#  'Club Sportivo Buenos Aires from Argentina',
#  'Club Toluca from Mexico',
#  'Clyde from Scotland',
#  'Cobreloa from Chile',
#  'Colegio Nacional de Iquitos from Peru',
#  'Coleraine from Northern Ireland',
#  'Colo Colo from Chile',
#  'Colo-Colo from Chile',
#  'Colombe Sportive from Cameroon',
#  'Colorado Rapids from United States',
#  'Columbus Crew from United States',
#  'Colón de Santa Fe from Argentina',
#  'Colón from Argentina',
#  'Compostela from Spain',
#  'Comunicaciones from Guatemala',
#  'Constant Spring from Jamaica',
#  'Copenhagen from Denmark',
#  'Coquimbo Unido from Chile',
#  'Corinthians from Brazil',
#  'Coton Sport from Cameroon',
#  'Cotonsport Garoua from Cameroon',
#  'Cottonsport Garoua from Cameroon',
#  'Coventry City from England',
#  'Cracovia from Poland',
#  'Cremonese from Italy',
#  'Crewe Alexandra from England',
#  'Crişana Oradea from Romania',
#  'Crișana Oradea from Romania',
#  'Croatia Zagreb from Croatia',
#  'Crotone from Italy',
#  'Cruz Azul from Mexico',
#  'Cruz Azul[19] from Mexico',
#  'Cruz Azul[30] from Mexico',
#  'Cruz Azul[38] from Mexico',
#  'Cruz Azul[41] from Mexico',
#  'Cruzeiro from Brazil',
#  'Crystal Palace from England',
#  'Crystal Palace[56] from England',
#  'Créteil from France',
#  'Csepeli Vasas from Hungary',
#  'Cádiz from Spain',
#  'Córdoba from Spain',
#  'D.C. United from United States',
#  'DCS Irboual from Zaire',
#  'DFC Dordrecht from Netherlands',
#  'DFS Lokomotiv Plovdiv from Bulgaria',
#  'DH Jadida from Morocco',
#  'DHC from Netherlands',
#  'DNC Alger from Algeria',
#  'DSV Alpine Donawitz from Austria',
#  'DWB from Netherlands',
#  'DWS from Netherlands',
#  'Daegu FC from South Korea',
#  'Daejeon Citizen from South Korea',
#  'Daejeon Hana Citizen from South Korea',
#  'Daewoo Royals from South Korea',
#  'Dalian Shide from China',
#  'Dalian Yifang from China',
#  'Danubio from Uruguay',
#  'Daring Club de Bruxelles Societe Royale from Belgium',
#  'Daring Club de Bruxelles Société Royale from Belgium',
#  'Daring Club from Belgium',
#  'Debrecen from Hungary',
#  'Debreceni Bocskai from Hungary',
#  'Defensor Sporting from Uruguay',
#  'Defensor from Uruguay',
#  'Defensores de Belgrano from Argentina',
#  'Degerfors IF from Sweden',
#  'Deinze from Belgium',
#  'Denizlispor from Turkey',
#  'Deportes Temuco from Chile',
#  'Deportes Tolima from Colombia',
#  'Deportivo Cali from Colombia',
#  'Deportivo Español from Argentina',
#  'Deportivo Fabril from Spain',
#  'Deportivo Guadalajara from Mexico',
#  'Deportivo Jalapa from Guatemala',
#  'Deportivo La Coruña from Spain',
#  'Deportivo La Coruña[28] from Spain',
#  'Deportivo Mexico from Mexico',
#  'Deportivo Municipal from Peru',
#  'Deportivo Naval from Chile',
#  'Deportivo Pereira from Colombia',
#  'Deportivo Quito from Ecuador',
#  'Derby County from England',
#  'Destroyers from Bolivia',
#  'Detroit Holley Carburetor from United States',
#  'Dijon from France',
#  'Dinamo Bacău from Romania',
#  'Dinamo București from Romania',
#  'Dinamo Minsk from Soviet Union',
#  'Dinamo Tbilisi from Soviet Union',
#  'Dinamo Zagreb from Croatia',
#  'Dinamo Zagreb from Yugoslavia',
#  'Dinamo Zagreb[68] from Croatia',
#  'Diósgyőri VTK from Hungary',
#  'Djoliba from Mali',
#  'Djurgården from Sweden',
#  'Djurgårdens IF from Sweden',
#  'Dnipro Dnipropetrovsk from Soviet Union',
#  'Dnipro Dnipropetrovsk from Ukraine',
#  'Dobrudzha Tolbuchin from Bulgaria',
#  'Don Bosco from Haiti',
#  'Doncaster Rovers from England',
#  'Donostia from Spain',
#  'Dorogi AC from Hungary',
#  'Dorogi Bányász from Hungary',
#  'Drafn from Norway',
#  'Dragon Douala from Cameroon',
#  'Dragoș Vodă Cernăuți from Romania',
#  'Dresdner SC from Germany',
#  'Dukla Pardubice from Czechoslovakia',
#  'Dukla Prague from Czechoslovakia',
#  'Dunajská Streda from Czechoslovakia',
#  'Dunajská Streda from Slovakia',
#  'Dundee United from Scotland',
#  'Dundee from Scotland',
#  'Dynamo Douala from Cameroon',
#  'Dynamo Dresden from Germany',
#  'Dynamo Dresden[61] from Germany',
#  'Dynamo Kyiv from Soviet Union',
#  'Dynamo Kyiv from Ukraine',
#  'Dynamo Kyiv[67] from Ukraine',
#  'Dynamo Minsk from Soviet Union',
#  'Dynamo Moscow from Russia',
#  'Dynamo Moscow from Soviet Union',
#  'Dynamo Moscow[43] from Russia',
#  'Dynamo Moscow[44] from Russia',
#  'Dynamo Praha from Czechoslovakia',
#  'Dynamo České Budějovice from Czech Republic',
#  'Dąb Katowice from Poland',
#  'ES Sétif from Algeria',
#  'East Coast Bays from New Zealand',
#  'Edmonton Brick Men from Canada',
#  'Eendracht Aalst from Belgium',
#  'Eibar from Spain',
#  'Eintracht Braunschweig from Germany',
#  'Eintracht Braunschweig[113] from Germany',
#  'Eintracht Braunschweig[118] from Germany',
#  'Eintracht Frankfurt from Germany',
#  'Eintracht Trier from Germany',
#  'El Nacional from Ecuador',
#  'El Nacional[2] from Ecuador',
#  'El Nacional[3] from Ecuador',
#  'El-Olympi Alexandria from Egypt',
#  'Elazığspor from Turkey',
#  'Elche from Spain',
#  'Elfsborg from Sweden',
#  'Emelec from Ecuador',
#  'Energie Cottbus from Germany',
#  'Energie Cottbus[55] from Germany',
#  'Enugu Rangers[122] from Nigeria',
#  'Enyimba from Nigeria',
#  'Espanyol from Spain',
#  'Español from Spain',
#  'Espérance de Tunis from Tunisia',
#  'Espérance from Tunisia',
#  'Esteghlal from Iran',
#  'Estudiantes (LP) from Argentina',
#  'Estudiantes La Plata from Argentina',
#  'Estudiantes from Argentina',
#  'Estudiantil Porteño from Argentina',
#  'Etar Veliko Tarnovo from Bulgaria',
#  'Eupen from Belgium',
#  'Everton from Chile',
#  'Everton from England',
#  'Everton[147] from England',
#  'Evian from France',
#  'Excelsior AC Roubaix from France',
#  'Excelsior Roubaix from France',
#  'Excelsior Soerabaja from Dutch East Indies',
#  'Extremadura from Spain',
#  'F.C. Hansa Rostock from Germany',
#  'FAR Rabat from Morocco',
#  'FAS from El Salvador',
#  'FC Amsterdam from Netherlands',
#  'FC Atlante from Mexico',
#  'FC Augsburg from Germany',
#  'FC Augsburg[158] from Germany',
#  'FC Basel from Switzerland',
#  'FC Bayern Munchen from Germany',
#  'FC Bern from Switzerland',
#  'FC Carl Zeiss Jena from Germany',
#  'FC Chiasso from Switzerland',
#  'FC Cincinnati from United States',
#  'FC Dallas from United States',
#  'FC Excelsior Hasselt from Belgium',
#  'FC Girondins de Bordeaux from France',
#  'FC Grenchen from Switzerland',
#  'FC La Chaux-de-Fonds from Switzerland',
#  'FC León from Mexico',
#  'FC Liège from Belgium',
#  'FC Locarno from Switzerland',
#  'FC Lugano from Switzerland',
#  'FC Luzern from Switzerland',
#  'FC Metz from France',
#  'FC Moscow from Russia',
#  'FC Nyiki from Zaire',
#  'FC Oviedo from Spain',
#  'FC Puebla from Mexico',
#  'FC Rot-Weiss Erfurt from Germany',
#  'FC Rouen from France',
#  'FC Schalke 04 from Germany',
#  'FC Seoul from South Korea',
#  'FC Sochaux from France',
#  'FC Sochaux-Montbéliard from France',
#  'FC Spartak Trnava from Czechoslovakia',
#  'FC St. Pauli from Germany',
#  'FC Sète from France',
#  'FC Tampa Bay from United States',
#  'FC Tokyo from Japan',
#  'FC Utrecht from Netherlands',
#  'FC Vorwärts Frankfurt (Oder) from Germany',
#  'FC Zurich from Switzerland',
#  'FK Pirmasens from Germany',
#  'FSV Frankfurt from Germany',
#  'FSV Frankfurt[36] from Germany',
#  'FV Saarbrücken from Germany',
#  'Fagiano Okayama from Japan',
#  'Falkirk from Scotland',
#  'Fall River Marksmen from United States',
#  'Farense from Portugal',
#  'Farul Constanța from Romania',
#  'Federico Schwager from Chile',
#  'Feijenoord from Netherlands',
#  'Fenerbahçe SK from Turkey',
#  'Fenerbahçe from Turkey',
#  'Ferencváros FC from Hungary',
#  'Ferencváros from Hungary',
#  'Ferencvárosi TC from Hungary',
#  'Ferencvárosi from Hungary',
#  'Ferro Carril Oeste from Argentina',
#  'Ferroviario La Paz from Bolivia',
#  'Fethiyespor[18] from Turkey',
#  'Feyenoord from Netherlands',
#  'Feyenoord[84] from Netherlands',
#  'Figueres from Spain',
#  'Fiorentina from Italy',
#  'Fiorentina[69] from Italy',
#  'First Vienna FC from Austria',
#  'First Vienna from Austria',
#  'First Vienna[F] from Germany',
#  'Fives from France',
#  'Flamengo from Brazil',
#  'Flamengo* from Brazil',
#  'Fluminense from Brazil',
#  'Foggia from Italy',
#  'Foolad from Iran',
#  'Footscray JUST from Australia',
#  'Fort Lauderdale Strikers from United States',
#  'Fortuna Düsseldorf from Germany',
#  'Fram Larvik from Norway',
#  'Fredrikstad from Norway',
#  'Free Agent from -',
#  'Free agent from Argentina',
#  'Fulham F.C. from England',
#  'Fulham from England',
#  'Fédéral SFC du Noun from Cameroon',
#  'GAIS from Sweden',
#  'GCR Mascara from Algeria',
#  'GKS Katowice from Poland',
#  'Gabros International from Nigeria',
#  'Galatasaray S.K. from Turkey',
#  'Galatasaray from Turkey',
#  'Galatasaray[115] from Turkey',
#  'Galaxy from Jamaica',
#  'Gamba Osaka from Japan',
#  'Gaziantepspor from Turkey',
#  'Gefle IF from Sweden',
#  'Genk from Belgium',
#  'Genoa from Italy',
#  'Gent from Belgium',
#  'Germinal Beerschot from Belgium',
#  'Germinal Ekeren from Belgium',
#  'Getafe from Spain',
#  'Getafe[81] from Spain',
#  'Ghazl El-Mehalla from Egypt',
#  'Gie Hoo Soerabaja from Dutch East Indies',
#  'Gil Vicente from Portugal',
#  'Gillingham from England',
#  'Gimcheon Sangmu from South Korea',
#  'Gimnasia de Jujuy from Argentina',
#  'Gimnasia y Esgrima LP from Argentina',
#  'Gimnasia y Esgrima de Mendoza from Argentina',
#  'Girona from Spain',
#  'Girondins de Bordeaux from France',
#  'Gisborne City from New Zealand',
#  'Glenavon from Northern Ireland',
#  'Glentoran from Northern Ireland',
#  'Gloria Arad from Romania',
#  'Go Ahead Eagles Deventer from Netherlands',
#  'Go Ahead Eagles from Netherlands',
#  'Go Ahead Semarang from Dutch East Indies',
#  'Godoy Cruz from Argentina',
#  'Gold Coast United from Australia',
#  'Golden Arrows from South Africa',
#  'Gombe United from Nigeria',
#  'Granada from Spain',
#  'Granada[17] from Spain',
#  'Granada[56] from Spain',
#  'Grasshopper Club Zürich from Switzerland',
#  'Grasshopper from Switzerland',
#  'Grasshopper[107] from Switzerland',
#  'Grasshoppers Club Zurich from Switzerland',
#  'Grazer AK from Austria',
#  'Green Cross Temuco from Chile',
#  'Grenchen from Switzerland',
#  'Grenoble from France',
#  'Greuther Fürth from Germany',
#  'Grimsby Town from England',
#  'Groningen from Netherlands',
#  'Grêmio from Brazil',
#  'Guadalajara from Mexico',
#  'Guadalajara[37] from Mexico',
#  'Guanacasteca from Costa Rica',
#  'Guangzhou Evergrande from China',
#  'Guangzhou R&F from China',
#  'Guarani from Brazil',
#  'Guarani from Paraguay',
#  'Guaraní from Paraguay',
#  'Guard FC from Iran',
#  'Gueugnon from France',
#  'Guingamp from France',
#  'Guizhou Renhe from China',
#  'Gwangju Sangmu Phoenix from South Korea',
#  'Gwangju Sangmu from South Korea',
#  'Gwardia Warszawa from Poland',
#  'Győr from Hungary',
#  'Győri Vasas SE from Hungary',
#  'Győri from Hungary',
#  'Gårda BK from Sweden',
#  'Górnik Zabrze from Poland',
#  'Göteborg from Sweden',
#  'Göztepe from Turkey',
#  'HBS Craeyenhout from Netherlands',
#  'HBS Soerabaja from Dutch East Indies',
#  'HCTNH Soerabaja from Dutch East Indies',
#  'HFC Haarlem from Netherlands',
#  'Hajduk Split from Croatia',
#  'Hajduk Split from Yugoslavia',
#  'Hakoah Maccabi Ramat Gan from Israel',
#  'Haladás from Hungary',
#  'Hallelujah FC from South Korea',
#  'Hamburger SV from Germany',
#  'Hamburger SV[106] from Germany',
#  'Hamburger SV[70] from Germany',
#  'Hammarby IF from Sweden',
#  'Hammarby from Sweden',
#  'Hangzhou Greentown from China',
#  'Hanimex United from New Zealand',
#  'Hannover 96 from Germany',
#  'Hansa Rostock from Germany',
#  'Hanyang University from South Korea',
#  "Hapoel Be'er Sheva from Israel",
#  'Hapoel Haifa from Israel',
#  'Hapoel Jerusalem from Israel',
#  'Hapoel Kfar Saba from Israel',
#  'Hapoel Petah Tikva from Israel',
#  'Hapoel Tel Aviv from Israel',
#  'Harbour View from Jamaica',
#  'Hardy from Norway',
#  'Hatayspor from Turkey',
#  'Hazard United from Jamaica',
#  'Heart of Lions from Ghana',
#  'Heart of Midlothian from Scotland',
#  'Hearts from Scotland',
#  'Hearts of Oak from Ghana',
#  'Hebei China Fortune from China',
#  'Heerenveen from Netherlands',
#  'Heerenveen[124] from Netherlands',
#  'Hellas Verona from Italy',
#  'Helsingborg from Sweden',
#  'Helsingborgs IF from Sweden',
#  'Heracles Almelo from Netherlands',
#  'Hercules Batavia from Dutch East Indies',
#  'Herediano from Costa Rica',
#  'Hertha BSC from Germany',
#  'Hertha BSC[66] from Germany',
#  'Hibernian from Scotland',
#  'Hispano America from Cuba',
#  'Horoya from Guinea',
#  'Houston Dynamo FC from United States',
#  'Houston Dynamo from United States',
#  'Hrvatski Dragovoljac from Croatia',
#  'Huachipato from Chile',
#  'Huddersfield Town A.F.C. from England',
#  'Huddersfield Town from England',
#  'Hull City from England',
#  'Hungária from Hungary',
#  'Huracán from Argentina',
#  'Hyundai Horangi from South Korea',
#  'Häcken from Sweden',
#  'Hälsingborgs IF from Sweden',
#  'Hércules from Spain',
#  'IF Elfsborg Borås from Sweden',
#  'IF Elfsborg from Sweden',
#  'IFK Eskilstuna from Sweden',
#  'IFK Grängesberg from Sweden',
#  'IFK Göteborg from Sweden',
#  'IFK Göteborg[21] from Sweden',
#  'IFK Norrköping from Sweden',
#  'IK Sirius from Sweden',
#  'IK Sleipner from Sweden',
#  'ILSA Timișoara from Romania',
#  'IR Tanger from Morocco',
#  'IS Halmia from Sweden',
#  'Ibadan from Nigeria',
#  'Iberia Habana from Cuba',
#  'Iberia Havana from Cuba',
#  'Ilhwa Chunma from South Korea',
#  'Imbabura from Ecuador',
#  'Incheon United from South Korea',
#  'Independiente Medellín from Colombia',
#  'Independiente Santa Fe from Colombia',
#  'Independiente de San Vicente from El Salvador',
#  'Independiente del Valle from Ecuador',
#  'Independiente from Argentina',
#  'Inex Toronto from Canada',
#  'Inter Bratislava from Czechoslovakia',
#  'Inter Miami CF from United States',
#  'Inter Milan from Italy',
#  'Interclube from Angola',
#  'Internacional from Brazil',
#  'Internazionale Milan from Italy',
#  'Internazionale Milano F.C. from Italy',
#  'Internazionale from Italy',
#  'Internațional from Romania',
#  'Invercargill Thistle from New Zealand',
#  'Ipswich Town from England',
#  'Iraklis from Greece',
#  'Iskra Žilina from Czechoslovakia',
#  'Istanbulspor from Turkey',
#  'Istres from France',
#  'JE Tizi-Ouzou from Algeria',
#  'JEF United Ichihara from Japan',
#  'JEF United from Japan',
#  'JS El Biar from Algeria',
#  'JS Kairouan from Tunisia',
#  'JS Saint-Pierroise from Réunion',
#  'Jaguares[16] from Mexico',
#  'Jahn Regensburg from Germany',
#  'Jednota Trenčín from Czechoslovakia',
#  'Jeju United from South Korea',
#  'Jeonbuk Hyundai Motors from South Korea',
#  'Jeonnam Dragons from South Korea',
#  'Jomo Cosmos from South Africa',
#  'Jong Ambon Batavia from Dutch East Indies',
#  'Juan Aurich from Peru',
#  'Juventud Asturiana from Cuba',
#  'Juventud Olimpica from El Salvador',
#  'Juventus București from Romania',
#  'Juventus from Italy',
#  'Juventus[65] from Italy',
#  'Juárez from Mexico',
#  'Júbilo Iwata from Japan',
#  'KAC Kenitra from Morocco',
#  'KAC Marrakesh from Morocco',
#  'KB from Denmark',
#  'KFC (Kooger FC) from Netherlands',
#  'KSK Liersche from Belgium',
#  'KSV Hessen Kassel from Germany',
#  'KSV Waregem from Belgium',
#  'Kaizer Chiefs from South Africa',
#  'Kansas City Comets from United States',
#  'Kansas City Wizards from United States',
#  'Kapellen from Belgium',
#  'Kapfenberger SV from Austria',
#  'Kardemir Karabükspor from Turkey',
#  'Karlsruher SC from Germany',
#  'Kashima Antlers from Japan',
#  'Kashiwa Reysol from Japan',
#  'Kasımpaşa SK from Turkey',
#  'Kasımpaşa from Turkey',
#  'Kavala from Greece',
#  'Kawasaki Frontale from Japan',
#  'Kayseri Erciyesspor from Turkey',
#  'Kayserispor from Turkey',
#  'Kayserispor[57] from Turkey',
#  'Kazma from Kuwait',
#  'Kenitra from Morocco',
#  'Khaitan from Kuwait',
#  'Kharkiv[85] from Ukraine',
#  'Kickers Offenbach from Germany',
#  'Kigwancha from North Korea',
#  'Kilmarnock from Scotland',
#  'King Faisal Babes from Ghana',
#  'Kispest from Hungary',
#  'Kocaelispor from Turkey',
#  'Koninklijke HFC from Netherlands',
#  'Konkuk University from South Korea',
#  'Konyaspor from Turkey',
#  'Konyaspor[13] from Turkey',
#  'Koper from Slovenia',
#  'Korea University from South Korea',
#  'Kortrijk from Belgium',
#  'Krasnodar from Russia',
#  'Krylya Sovetov Samara from Russia',
#  'KuPS from Finland',
#  'Kuban Krasnodar from Russia',
#  'Kuwait SC from Kuwait',
#  'Kyonggongop from North Korea',
#  'Kyoto Purple Sanga from Japan',
#  'Kyung Hee University from South Korea',
#  'Křídla vlasti Olomouc from Czechoslovakia',
#  "L'Hospitalet from Spain",
#  'LA Galaxy from United States',
#  'LA Galaxy[54] from United States',
#  'LASK from Austria',
#  'LDU Quito from Ecuador',
#  'LDU Quito[5] from Ecuador',
#  'LG Cheetahs from South Korea',
#  'La Chaux-de-Fonds from Switzerland',
#  'La Cruz FC from Chile',
#  'La Louviére from Belgium',
#  'La Roche Vendée from France',
#  'La Tour-de-Peilz from Switzerland',
#  'Laguna from Mexico',
#  'Landskrona BoIS from Sweden',
#  'Lanús from Argentina',
#  'Larissa from Greece',
#  'Las Palmas from Spain',
#  'Lausanne Sports from Switzerland',
#  'Lausanne from Switzerland',
#  'Lausanne-Sport from Switzerland',
#  'Laval from France',
#  'Lawn Tennis de la Exposición from Peru',
#  'Lazio from Italy',
#  'Lazio[139] from Italy',
#  'Le Havre AC from France',
#  'Le Havre from France',
#  'Le Mans from France',
#  'Lecce from Italy',
#  'Lech Poznań from Poland',
#  'Lech Poznań[13] from Poland',
#  'Lechia Gdańsk from Poland',
#  'Leeds United from England',
#  ...]

# %%
len(clubs_or)
# Out:
# 1971

# %% [markdown]
# Hay algunos nombres de clubes que vienen con una referencia en los datos originales, para eliminarla vamos a utilizar regular expresions

# %%
import re

# %%
# Utilizar el método .str.replace() para realizar la sustitución.Es lo mismo que hacerlo con apply + función anónima pero 
# más eficiente.
clubs['club_and_origin'] = clubs['club_and_origin'].str.replace(r'\[\d+\]', '', regex=True)

# %%
clubs_or = clubs.club_and_origin.unique().tolist()

# %%
len(clubs_or)
# Out:
# 1809

# %%
sorted(clubs_or)
# Out:
# ['1. FC Kaiserslautern from Germany',
#  '1. FC Köln from Germany',
#  '1. FC Lokomotive Leipzig from Germany',
#  '1. FC Magdeburg from Germany',
#  '1. FC Nürnberg from Germany',
#  '1. FC Saarbrücken from Germany',
#  '1. FC Schweinfurt 05 from Germany',
#  '1. Simmeringer SC from Austria',
#  '1860 Munich from Germany',
#  '1899 Hoffenheim from Germany',
#  '8 August from North Korea',
#  '8 February from North Korea',
#  'A.C. Mantova from Italy',
#  'A.S.V. Oostende K.M. from Belgium',
#  'AC Bellinzona from Switzerland',
#  'AC Sparta Prague from Czechoslovakia',
#  'ADO Den Haag from Netherlands',
#  'AEK Athens F.C. from Greece',
#  'AEK Athens from Greece',
#  'AFC Bournemouth from England',
#  'AFC Wimbledon from England',
#  'AGF from Denmark',
#  'AIK from Sweden',
#  'AKS Chorzów from Poland',
#  'AMEF Arad from Romania',
#  'APIA Leichhardt from Australia',
#  'APOEL from Cyprus',
#  'AS Bilima from Zaire',
#  'AS Marsa from Tunisia',
#  'AS Monaco from France',
#  'AS Saint-Étienne from France',
#  'AS Sale from Morocco',
#  'AS Troyes from France',
#  'AS Vita Club from Zaire',
#  'ASA from Angola',
#  "ASC Jeanne d'Arc from Senegal",
#  'ASEC Mimosas from Ivory Coast',
#  'ASO Chlef from Algeria',
#  'AZ from Netherlands',
#  'AaB from Denmark',
#  'Aalesund from Norway',
#  'Aarau from Switzerland',
#  'Aberdeen from Scotland',
#  'Abha from Saudi Arabia',
#  'Abu Moslem from Iran',
#  'Académica de Coimbra from Portugal',
#  'Adalet SK Istanbul from Turkey',
#  'Adelaide City from Australia',
#  'Adelaide United from Australia',
#  'Adler San Nicolas from El Salvador',
#  'Admira Wacker from Austria',
#  'Admira Wien from Austria',
#  'Admira Wien[F] from Germany',
#  'Admira/Wacker from Austria',
#  'Aduana Stars from Ghana',
#  'Africa Sports from Ivory Coast',
#  'Aigle Noir from Haiti',
#  'Airdrieonians from Scotland',
#  'Ajaccio from France',
#  'Ajax Amsterdam from Netherlands',
#  'Ajax Cape Town from South Africa',
#  'Ajax from Netherlands',
#  'Akademik Sofia from Bulgaria',
#  'Akademisk from Denmark',
#  'Akhmat Grozny from Russia',
#  'Al Ahli from Saudi Arabia',
#  'Al Ahly from Egypt',
#  'Al Ain from United Arab Emirates',
#  'Al Batin from Saudi Arabia',
#  'Al Ettifaq from Saudi Arabia',
#  'Al Fateh from Saudi Arabia',
#  'Al Hilal from Saudi Arabia',
#  'Al Jazira from United Arab Emirates',
#  'Al Khaleej Club from United Arab Emirates',
#  'Al Nassr from Saudi Arabia',
#  'Al Qadsiah from Saudi Arabia',
#  'Al Raed from Saudi Arabia',
#  'Al Sadd from Qatar',
#  'Al Shaab from United Arab Emirates',
#  'Al Shabab from Saudi Arabia',
#  'Al Shabab from United Arab Emirates',
#  'Al Taawoun from Saudi Arabia',
#  'Al Tadamun from Kuwait',
#  'Al-Ahli Doha from Qatar',
#  'Al-Ahli from Saudi Arabia',
#  'Al-Ahli from United Arab Emirates',
#  'Al-Arabi from Kuwait',
#  'Al-Arabi from Qatar',
#  'Al-Duhail from Qatar',
#  'Al-Ettifaq from Saudi Arabia',
#  'Al-Fateh from Saudi Arabia',
#  'Al-Gharafa from Qatar',
#  'Al-Hilal from Saudi Arabia',
#  'Al-Ittihad from Egypt',
#  'Al-Ittihad from Saudi Arabia',
#  'Al-Jaish from Iraq',
#  'Al-Khaleej from Saudi Arabia',
#  'Al-Kuwait from Kuwait',
#  'Al-Masry AC Port Said from Egypt',
#  'Al-Masry from Egypt',
#  'Al-Nasr from United Arab Emirates',
#  'Al-Nassr from Saudi Arabia',
#  'Al-Olympi Alexandria from Egypt',
#  'Al-Qadsia from Kuwait',
#  'Al-Rasheed from Iraq',
#  'Al-Rayyan from Qatar',
#  'Al-Riyadh from Saudi Arabia',
#  'Al-Sadd from Qatar',
#  'Al-Salmiya from Kuwait',
#  'Al-Shabab from Iraq',
#  'Al-Shabab from Saudi Arabia',
#  'Al-Sharjah from United Arab Emirates',
#  'Al-Shorta from Iraq',
#  'Al-Siliyah from Qatar',
#  "Al-Ta'ee from Saudi Arabia",
#  'Al-Tai from Saudi Arabia',
#  'Al-Talaba from Iraq',
#  'Al-Tayaran from Iraq',
#  'Al-Wakrah from Qatar',
#  'Al-Wasl from United Arab Emirates',
#  'Al-Wehda from Saudi Arabia',
#  'Alajuelense from Costa Rica',
#  'Alania Vladikavkaz from Russia',
#  'Alanyaspor from Turkey',
#  'Alavés from Spain',
#  'Albany Capitals from United States',
#  'Albirex Niigata from Japan',
#  'Alemannia Aachen from Germany',
#  'Alianza Lima from Peru',
#  'Alianza Oruro from Bolivia',
#  'Alianza from El Salvador',
#  'Almagro from Argentina',
#  'Almería from Spain',
#  'Ambrosiana-Inter from Italy',
#  'America-RJ from Brazil',
#  'Americano-RJ from Brazil',
#  'Americano-RS from Brazil',
#  'Amiens AC from France',
#  'Amiens from France',
#  'Amkar Perm from Russia',
#  'Amrokgang from North Korea',
#  'América de Cali from Colombia',
#  'América from Mexico',
#  'Ancona from Italy',
#  'Anderlecht from Belgium',
#  'Angers from France',
#  'Ankaragücü from Turkey',
#  'Ankaraspor from Turkey',
#  'Antalyaspor from Turkey',
#  'Antwerp from Belgium',
#  'Anyang LG Cheetahs from South Korea',
#  'Anzhi Makhachkala from Russia',
#  'Apollon Smyrnis from Greece',
#  'April 25 from North Korea',
#  'Ararat Yerevan from Soviet Union',
#  'Archibald from Trinidad and Tobago',
#  'Argentino (Q) from Argentina',
#  'Argentinos Juniors from Argentina',
#  'Argeș Pitești from Romania',
#  'Aris from Greece',
#  'Arka Gdynia from Poland',
#  'Arles-Avignon from France',
#  'Arminia Bielefeld from Germany',
#  'Arnett Gardens from Jamaica',
#  'Arsenal F.C. from England',
#  'Arsenal Tula from Russia',
#  'Arsenal from England',
#  'Arturo Fernández Vial from Chile',
#  'Asan Mugunghwa from South Korea',
#  'Asante Kotoko from Ghana',
#  'Ashanti Gold from Ghana',
#  'Ashdod from Israel',
#  'Aston Villa from England',
#  'Asturias from Mexico',
#  'Atalanta from Italy',
#  'Athletic Bilbao from Spain',
#  'Athletico Paranaense from Brazil',
#  'Atlanta United FC from United States',
#  'Atlante F.C. from Mexico',
#  'Atlante San Alejo from El Salvador',
#  'Atlante from Mexico',
#  'Atlas from Mexico',
#  'Atlético Bilbao from Spain',
#  'Atlético Bucaramanga from Colombia',
#  'Atlético Chalaco from Peru',
#  'Atlético Español from Mexico',
#  'Atlético Junior from Colombia',
#  'Atlético Madrid from Spain',
#  'Atlético Marte from El Salvador',
#  'Atlético Mineiro from Brazil',
#  'Atlético Nacional from Colombia',
#  'Atlético Paranaense from Brazil',
#  'Atlético de Bilbao from Spain',
#  'Atromitos from Greece',
#  'Aucas from Ecuador',
#  'Auckland City from New Zealand',
#  'Audax Italiano from Chile',
#  'Austria Salzburg from Austria',
#  'Austria Vienna from Austria',
#  'Austria Wien from Austria',
#  'Auxerre from France',
#  'Avellino from Italy',
#  'BC Augsburg from Germany',
#  'BFC Dynamo from Germany',
#  'BSG Sachsenring Zwickau from Germany',
#  'BSK Beograd from Yugoslavia',
#  'BV Borussia Dortmund from Germany',
#  'Bahman from Iran',
#  'Baltimore Blast from United States',
#  'Baltimore Canton from United States',
#  'Banatul Timișoara from Romania',
#  'Banfield from Argentina',
#  'Bangu from Brazil',
#  'Baník Handlová from Czechoslovakia',
#  'Baník Kladno from Czechoslovakia',
#  'Baník Ostrava from Czechoslovakia',
#  'Barcelona SC from Ecuador',
#  'Barcelona from Ecuador',
#  'Barcelona from Spain',
#  'Bargh Shiraz from Iran',
#  'Bari from Italy',
#  'Barracas Central from Argentina',
#  'Barreirense from Portugal',
#  'Basel from Switzerland',
#  'Bastia from France',
#  'Bayer Leverkusen from Germany',
#  'Bayer Uerdingen from Germany',
#  'Bayern Munich from Germany',
#  'Be Quick 1887 from Netherlands',
#  'Bechem Chelsea from Ghana',
#  'Beerschot from Belgium',
#  "Beijing Guo'an from China",
#  'Beijing Guoan from China',
#  'Beijing Sinobo Guoan from China',
#  'Beira-Mar from Portugal',
#  'Belenenses from Portugal',
#  'Bella Vista from Uruguay',
#  'Bellmare Hiratsuka from Japan',
#  'Ben Millers from United States',
#  'Benevento from Italy',
#  'Benfica from Portugal',
#  'Berchem Sport from Belgium',
#  'Bern from Switzerland',
#  'Beroe Stara Zagora from Bulgaria',
#  'Besançon from France',
#  'Beveren from Belgium',
#  'Beşiktaş J.K. from Turkey',
#  'Beşiktaş from Turkey',
#  'Bienne-Biel from Switzerland',
#  'Birmingham City from England',
#  'Bizertin from Tunisia',
#  'Blackburn Rovers F.C. from England',
#  'Blackburn Rovers from England',
#  'Blackpool F.C. from England',
#  'Blackpool from England',
#  'Bloemfontein Celtic from South Africa',
#  'Blooming from Bolivia',
#  'Bnei Yehuda from Israel',
#  'Boavista from Portugal',
#  'Boca Juniors Antofagasta from Chile',
#  'Boca Juniors from Argentina',
#  'Bohemians Praha from Czechoslovakia',
#  'Bolivar from Bolivia',
#  'Bologna from Italy',
#  'Bolton Wanderers from England',
#  'Bolívar from Bolivia',
#  'Borac Banja Luka from Bosnia and Herzegovina',
#  'Bordeaux from France',
#  'Borussia Dortmund from Germany',
#  'Borussia Mönchengladbach from Germany',
#  'Botafogo from Brazil',
#  'Botev Plovdiv from Bulgaria',
#  'Botev Vratsa from Bulgaria',
#  'Bournemouth from England',
#  'Bradford City from England',
#  'Braga from Portugal',
#  'Brașov from Romania',
#  'Brentford from England',
#  'Brescia from Italy',
#  'Brest from France',
#  'Brighton & Hove Albion from England',
#  'Brisbane Roar from Australia',
#  'Bristol City from England',
#  'Brookhattan from United States',
#  'Brooklyn Celtic from United States',
#  'Brooklyn Hispano from United States',
#  'Brujas from Costa Rica',
#  'Brøndby from Denmark',
#  'Brønshøj from Denmark',
#  'Bucheon SK from South Korea',
#  'Budapest Honvéd FC from Hungary',
#  'Budapest Honvéd from Hungary',
#  'Budapesti Dózsa from Hungary',
#  'Budapesti Honvéd SE from Hungary',
#  'Budapesti Kinizsi from Hungary',
#  'Budapesti Vasas SE from Hungary',
#  'Budapesti Vörös Lobogó from Hungary',
#  'Budućnost Titograd from Yugoslavia',
#  'Burnley F.C. from England',
#  'Burnley from England',
#  'Bursaspor from Turkey',
#  'Bury from England',
#  'Busan Daewoo Royals from South Korea',
#  "Busan I'Cons from South Korea",
#  'Busan IPark from South Korea',
#  'Békéscsabai Előre from Hungary',
#  'CA Bizertin from Tunisia',
#  'CA Paris from France',
#  'CA Timișoara from Romania',
#  'CAO Oradea from Romania',
#  'CASG Paris from France',
#  'CD Chalatenango from El Salvador',
#  'CD Cuautla from Mexico',
#  'CD Guadalajara from Mexico',
#  'CD Ingavi from Bolivia',
#  'CD Marte from Mexico',
#  'CD Olimpia from Honduras',
#  'CD Oro from Mexico',
#  'CD Real Sociedad from Honduras',
#  'CD Santiago from Chile',
#  'CD Tampico from Mexico',
#  'CD Zacatepec from Mexico',
#  'CDNA Sofia from Bulgaria',
#  'CF Atlas from Mexico',
#  'CF Barcelona from Spain',
#  'CF Monterrey from Mexico',
#  'CF Montréal from Canada',
#  'CH Bratislava from Czechoslovakia',
#  'CKD Praha from Czechoslovakia',
#  'CM Belcourt from Algeria',
#  'CODM Meknes from Morocco',
#  'COT Tunis from Tunisia',
#  'CS Constantine from Algeria',
#  'CS Imana from Zaire',
#  'CS Sfaxien from Tunisia',
#  'CSKA Moscow from Russia',
#  'CSKA Moscow from Soviet Union',
#  'CSKA SZ Sofia from Bulgaria',
#  'CSKA Sofia from Bulgaria',
#  'Caen from France',
#  'Cagliari from Italy',
#  'Cairo Shourta Police from Egypt',
#  'Calavera La Paz from Bolivia',
#  'Calcio Catania from Italy',
#  'Cambridge United from England',
#  'Cannes from France',
#  'Canon Yaounde from Cameroon',
#  'Canon Yaoundé from Cameroon',
#  'Canterbury United from New Zealand',
#  'Cantonal Neuchâtel from Switzerland',
#  'Cape Town Spurs from South Africa',
#  'Cardiff City from Wales',
#  'Cartaginés from Costa Rica',
#  'Catania from Italy',
#  'Celta Vigo from Spain',
#  'Celtic from Scotland',
#  'Central Coast Mariners from Australia',
#  'Central Norte from Argentina',
#  'Central from Uruguay',
#  'Centro Gallego from Cuba',
#  'Cercle Brugge from Belgium',
#  'Cerezo Osaka from Japan',
#  'Cerro Corá from Paraguay',
#  'Cerro Porteño from Paraguay',
#  'Cerro from Uruguay',
#  'Cesena from Italy',
#  'Chabab Mohammedia from Morocco',
#  'Chabab Mohammédia from Morocco',
#  'Changchun Yatai from China',
#  'Charleroi SC from Belgium',
#  'Charleroi from Belgium',
#  'Charlotte FC from United States',
#  'Charlton Athletic from England',
#  'Chaves from Portugal',
#  'Chelsea from England',
#  'Cheonan Ilhwa Chunma from South Korea',
#  'Cherno More Varna from Bulgaria',
#  'Chesterfield from England',
#  'Chiapas from Mexico',
#  'Chicago Eagles from United States',
#  'Chicago Fire FC from United States',
#  'Chicago Fire from United States',
#  'Chicago Slovak from United States',
#  'Chicago Sting from United States',
#  'Chicago Vikings from United States',
#  'Chicago Wonderbolts from United States',
#  'Chievo from Italy',
#  'Chinezul Timișoara from Romania',
#  'Chippa United from South Africa',
#  'Chivas USA from United States',
#  'Chornomorets Odesa from Soviet Union',
#  'Chorrillo from Panama',
#  'Chosun Textile Company FC from South Korea',
#  'Chosun University from South Korea',
#  'Châteauroux from France',
#  'Chênois from Switzerland',
#  'Ciudad de Murcia from Spain',
#  'Clermont from France',
#  'Cleveland Force from United States',
#  'Cleveland Slavia from United States',
#  'Club Africain from Tunisia',
#  'Club América from Mexico',
#  'Club Atletico Estudiantil Porteño from Argentina',
#  'Club Atlético Estudiantil Porteño from Argentina',
#  'Club Bolivar from Bolivia',
#  'Club Bolívar from Bolivia',
#  'Club Brugge from Belgium',
#  'Club Deportivo Marte from Mexico',
#  'Club Français from France',
#  'Club Irapuato from Mexico',
#  'Club Jorge Wilstermann from Bolivia',
#  'Club León from Mexico',
#  'Club Libertad from Paraguay',
#  'Club Litoral from Bolivia',
#  'Club San José from Bolivia',
#  'Club Sportivo Alsina from Argentina',
#  'Club Sportivo Buenos Aires from Argentina',
#  'Club Toluca from Mexico',
#  'Clyde from Scotland',
#  'Cobreloa from Chile',
#  'Colegio Nacional de Iquitos from Peru',
#  'Coleraine from Northern Ireland',
#  'Colo Colo from Chile',
#  'Colo-Colo from Chile',
#  'Colombe Sportive from Cameroon',
#  'Colorado Rapids from United States',
#  'Columbus Crew from United States',
#  'Colón de Santa Fe from Argentina',
#  'Colón from Argentina',
#  'Compostela from Spain',
#  'Comunicaciones from Guatemala',
#  'Constant Spring from Jamaica',
#  'Copenhagen from Denmark',
#  'Coquimbo Unido from Chile',
#  'Corinthians from Brazil',
#  'Coton Sport from Cameroon',
#  'Cotonsport Garoua from Cameroon',
#  'Cottonsport Garoua from Cameroon',
#  'Coventry City from England',
#  'Cracovia from Poland',
#  'Cremonese from Italy',
#  'Crewe Alexandra from England',
#  'Crişana Oradea from Romania',
#  'Crișana Oradea from Romania',
#  'Croatia Zagreb from Croatia',
#  'Crotone from Italy',
#  'Cruz Azul from Mexico',
#  'Cruzeiro from Brazil',
#  'Crystal Palace from England',
#  'Créteil from France',
#  'Csepeli Vasas from Hungary',
#  'Cádiz from Spain',
#  'Córdoba from Spain',
#  'D.C. United from United States',
#  'DCS Irboual from Zaire',
#  'DFC Dordrecht from Netherlands',
#  'DFS Lokomotiv Plovdiv from Bulgaria',
#  'DH Jadida from Morocco',
#  'DHC from Netherlands',
#  'DNC Alger from Algeria',
#  'DSV Alpine Donawitz from Austria',
#  'DWB from Netherlands',
#  'DWS from Netherlands',
#  'Daegu FC from South Korea',
#  'Daejeon Citizen from South Korea',
#  'Daejeon Hana Citizen from South Korea',
#  'Daewoo Royals from South Korea',
#  'Dalian Shide from China',
#  'Dalian Yifang from China',
#  'Danubio from Uruguay',
#  'Daring Club de Bruxelles Societe Royale from Belgium',
#  'Daring Club de Bruxelles Société Royale from Belgium',
#  'Daring Club from Belgium',
#  'Debrecen from Hungary',
#  'Debreceni Bocskai from Hungary',
#  'Defensor Sporting from Uruguay',
#  'Defensor from Uruguay',
#  'Defensores de Belgrano from Argentina',
#  'Degerfors IF from Sweden',
#  'Deinze from Belgium',
#  'Denizlispor from Turkey',
#  'Deportes Temuco from Chile',
#  'Deportes Tolima from Colombia',
#  'Deportivo Cali from Colombia',
#  'Deportivo Español from Argentina',
#  'Deportivo Fabril from Spain',
#  'Deportivo Guadalajara from Mexico',
#  'Deportivo Jalapa from Guatemala',
#  'Deportivo La Coruña from Spain',
#  'Deportivo Mexico from Mexico',
#  'Deportivo Municipal from Peru',
#  'Deportivo Naval from Chile',
#  'Deportivo Pereira from Colombia',
#  'Deportivo Quito from Ecuador',
#  'Derby County from England',
#  'Destroyers from Bolivia',
#  'Detroit Holley Carburetor from United States',
#  'Dijon from France',
#  'Dinamo Bacău from Romania',
#  'Dinamo București from Romania',
#  'Dinamo Minsk from Soviet Union',
#  'Dinamo Tbilisi from Soviet Union',
#  'Dinamo Zagreb from Croatia',
#  'Dinamo Zagreb from Yugoslavia',
#  'Diósgyőri VTK from Hungary',
#  'Djoliba from Mali',
#  'Djurgården from Sweden',
#  'Djurgårdens IF from Sweden',
#  'Dnipro Dnipropetrovsk from Soviet Union',
#  'Dnipro Dnipropetrovsk from Ukraine',
#  'Dobrudzha Tolbuchin from Bulgaria',
#  'Don Bosco from Haiti',
#  'Doncaster Rovers from England',
#  'Donostia from Spain',
#  'Dorogi AC from Hungary',
#  'Dorogi Bányász from Hungary',
#  'Drafn from Norway',
#  'Dragon Douala from Cameroon',
#  'Dragoș Vodă Cernăuți from Romania',
#  'Dresdner SC from Germany',
#  'Dukla Pardubice from Czechoslovakia',
#  'Dukla Prague from Czechoslovakia',
#  'Dunajská Streda from Czechoslovakia',
#  'Dunajská Streda from Slovakia',
#  'Dundee United from Scotland',
#  'Dundee from Scotland',
#  'Dynamo Douala from Cameroon',
#  'Dynamo Dresden from Germany',
#  'Dynamo Kyiv from Soviet Union',
#  'Dynamo Kyiv from Ukraine',
#  'Dynamo Minsk from Soviet Union',
#  'Dynamo Moscow from Russia',
#  'Dynamo Moscow from Soviet Union',
#  'Dynamo Praha from Czechoslovakia',
#  'Dynamo České Budějovice from Czech Republic',
#  'Dąb Katowice from Poland',
#  'ES Sétif from Algeria',
#  'East Coast Bays from New Zealand',
#  'Edmonton Brick Men from Canada',
#  'Eendracht Aalst from Belgium',
#  'Eibar from Spain',
#  'Eintracht Braunschweig from Germany',
#  'Eintracht Frankfurt from Germany',
#  'Eintracht Trier from Germany',
#  'El Nacional from Ecuador',
#  'El-Olympi Alexandria from Egypt',
#  'Elazığspor from Turkey',
#  'Elche from Spain',
#  'Elfsborg from Sweden',
#  'Emelec from Ecuador',
#  'Energie Cottbus from Germany',
#  'Enugu Rangers from Nigeria',
#  'Enyimba from Nigeria',
#  'Espanyol from Spain',
#  'Español from Spain',
#  'Espérance de Tunis from Tunisia',
#  'Espérance from Tunisia',
#  'Esteghlal from Iran',
#  'Estudiantes (LP) from Argentina',
#  'Estudiantes La Plata from Argentina',
#  'Estudiantes from Argentina',
#  'Estudiantil Porteño from Argentina',
#  'Etar Veliko Tarnovo from Bulgaria',
#  'Eupen from Belgium',
#  'Everton from Chile',
#  'Everton from England',
#  'Evian from France',
#  'Excelsior AC Roubaix from France',
#  'Excelsior Roubaix from France',
#  'Excelsior Soerabaja from Dutch East Indies',
#  'Extremadura from Spain',
#  'F.C. Hansa Rostock from Germany',
#  'FAR Rabat from Morocco',
#  'FAS from El Salvador',
#  'FC Amsterdam from Netherlands',
#  'FC Atlante from Mexico',
#  'FC Augsburg from Germany',
#  'FC Basel from Switzerland',
#  'FC Bayern Munchen from Germany',
#  'FC Bern from Switzerland',
#  'FC Carl Zeiss Jena from Germany',
#  'FC Chiasso from Switzerland',
#  'FC Cincinnati from United States',
#  'FC Dallas from United States',
#  'FC Excelsior Hasselt from Belgium',
#  'FC Girondins de Bordeaux from France',
#  'FC Grenchen from Switzerland',
#  'FC La Chaux-de-Fonds from Switzerland',
#  'FC León from Mexico',
#  'FC Liège from Belgium',
#  'FC Locarno from Switzerland',
#  'FC Lugano from Switzerland',
#  'FC Luzern from Switzerland',
#  'FC Metz from France',
#  'FC Moscow from Russia',
#  'FC Nyiki from Zaire',
#  'FC Oviedo from Spain',
#  'FC Puebla from Mexico',
#  'FC Rot-Weiss Erfurt from Germany',
#  'FC Rouen from France',
#  'FC Schalke 04 from Germany',
#  'FC Seoul from South Korea',
#  'FC Sochaux from France',
#  'FC Sochaux-Montbéliard from France',
#  'FC Spartak Trnava from Czechoslovakia',
#  'FC St. Pauli from Germany',
#  'FC Sète from France',
#  'FC Tampa Bay from United States',
#  'FC Tokyo from Japan',
#  'FC Utrecht from Netherlands',
#  'FC Vorwärts Frankfurt (Oder) from Germany',
#  'FC Zurich from Switzerland',
#  'FK Pirmasens from Germany',
#  'FSV Frankfurt from Germany',
#  'FV Saarbrücken from Germany',
#  'Fagiano Okayama from Japan',
#  'Falkirk from Scotland',
#  'Fall River Marksmen from United States',
#  'Farense from Portugal',
#  'Farul Constanța from Romania',
#  'Federico Schwager from Chile',
#  'Feijenoord from Netherlands',
#  'Fenerbahçe SK from Turkey',
#  'Fenerbahçe from Turkey',
#  'Ferencváros FC from Hungary',
#  'Ferencváros from Hungary',
#  'Ferencvárosi TC from Hungary',
#  'Ferencvárosi from Hungary',
#  'Ferro Carril Oeste from Argentina',
#  'Ferroviario La Paz from Bolivia',
#  'Fethiyespor from Turkey',
#  'Feyenoord from Netherlands',
#  'Figueres from Spain',
#  'Fiorentina from Italy',
#  'First Vienna FC from Austria',
#  'First Vienna from Austria',
#  'First Vienna[F] from Germany',
#  'Fives from France',
#  'Flamengo from Brazil',
#  'Flamengo* from Brazil',
#  'Fluminense from Brazil',
#  'Foggia from Italy',
#  'Foolad from Iran',
#  'Footscray JUST from Australia',
#  'Fort Lauderdale Strikers from United States',
#  'Fortuna Düsseldorf from Germany',
#  'Fram Larvik from Norway',
#  'Fredrikstad from Norway',
#  'Free Agent from -',
#  'Free agent from Argentina',
#  'Fulham F.C. from England',
#  'Fulham from England',
#  'Fédéral SFC du Noun from Cameroon',
#  'GAIS from Sweden',
#  'GCR Mascara from Algeria',
#  'GKS Katowice from Poland',
#  'Gabros International from Nigeria',
#  'Galatasaray S.K. from Turkey',
#  'Galatasaray from Turkey',
#  'Galaxy from Jamaica',
#  'Gamba Osaka from Japan',
#  'Gaziantepspor from Turkey',
#  'Gefle IF from Sweden',
#  'Genk from Belgium',
#  'Genoa from Italy',
#  'Gent from Belgium',
#  'Germinal Beerschot from Belgium',
#  'Germinal Ekeren from Belgium',
#  'Getafe from Spain',
#  'Ghazl El-Mehalla from Egypt',
#  'Gie Hoo Soerabaja from Dutch East Indies',
#  'Gil Vicente from Portugal',
#  'Gillingham from England',
#  'Gimcheon Sangmu from South Korea',
#  'Gimnasia de Jujuy from Argentina',
#  'Gimnasia y Esgrima LP from Argentina',
#  'Gimnasia y Esgrima de Mendoza from Argentina',
#  'Girona from Spain',
#  'Girondins de Bordeaux from France',
#  'Gisborne City from New Zealand',
#  'Glenavon from Northern Ireland',
#  'Glentoran from Northern Ireland',
#  'Gloria Arad from Romania',
#  'Go Ahead Eagles Deventer from Netherlands',
#  'Go Ahead Eagles from Netherlands',
#  'Go Ahead Semarang from Dutch East Indies',
#  'Godoy Cruz from Argentina',
#  'Gold Coast United from Australia',
#  'Golden Arrows from South Africa',
#  'Gombe United from Nigeria',
#  'Granada from Spain',
#  'Grasshopper Club Zürich from Switzerland',
#  'Grasshopper from Switzerland',
#  'Grasshoppers Club Zurich from Switzerland',
#  'Grazer AK from Austria',
#  'Green Cross Temuco from Chile',
#  'Grenchen from Switzerland',
#  'Grenoble from France',
#  'Greuther Fürth from Germany',
#  'Grimsby Town from England',
#  'Groningen from Netherlands',
#  'Grêmio from Brazil',
#  'Guadalajara from Mexico',
#  'Guanacasteca from Costa Rica',
#  'Guangzhou Evergrande from China',
#  'Guangzhou R&F from China',
#  'Guarani from Brazil',
#  'Guarani from Paraguay',
#  'Guaraní from Paraguay',
#  'Guard FC from Iran',
#  'Gueugnon from France',
#  'Guingamp from France',
#  'Guizhou Renhe from China',
#  'Gwangju Sangmu Phoenix from South Korea',
#  'Gwangju Sangmu from South Korea',
#  'Gwardia Warszawa from Poland',
#  'Győr from Hungary',
#  'Győri Vasas SE from Hungary',
#  'Győri from Hungary',
#  'Gårda BK from Sweden',
#  'Górnik Zabrze from Poland',
#  'Göteborg from Sweden',
#  'Göztepe from Turkey',
#  'HBS Craeyenhout from Netherlands',
#  'HBS Soerabaja from Dutch East Indies',
#  'HCTNH Soerabaja from Dutch East Indies',
#  'HFC Haarlem from Netherlands',
#  'Hajduk Split from Croatia',
#  'Hajduk Split from Yugoslavia',
#  'Hakoah Maccabi Ramat Gan from Israel',
#  'Haladás from Hungary',
#  'Hallelujah FC from South Korea',
#  'Hamburger SV from Germany',
#  'Hammarby IF from Sweden',
#  'Hammarby from Sweden',
#  'Hangzhou Greentown from China',
#  'Hanimex United from New Zealand',
#  'Hannover 96 from Germany',
#  'Hansa Rostock from Germany',
#  'Hanyang University from South Korea',
#  "Hapoel Be'er Sheva from Israel",
#  'Hapoel Haifa from Israel',
#  'Hapoel Jerusalem from Israel',
#  'Hapoel Kfar Saba from Israel',
#  'Hapoel Petah Tikva from Israel',
#  'Hapoel Tel Aviv from Israel',
#  'Harbour View from Jamaica',
#  'Hardy from Norway',
#  'Hatayspor from Turkey',
#  'Hazard United from Jamaica',
#  'Heart of Lions from Ghana',
#  'Heart of Midlothian from Scotland',
#  'Hearts from Scotland',
#  'Hearts of Oak from Ghana',
#  'Hebei China Fortune from China',
#  'Heerenveen from Netherlands',
#  'Hellas Verona from Italy',
#  'Helsingborg from Sweden',
#  'Helsingborgs IF from Sweden',
#  'Heracles Almelo from Netherlands',
#  'Hercules Batavia from Dutch East Indies',
#  'Herediano from Costa Rica',
#  'Hertha BSC from Germany',
#  'Hibernian from Scotland',
#  'Hispano America from Cuba',
#  'Horoya from Guinea',
#  'Houston Dynamo FC from United States',
#  'Houston Dynamo from United States',
#  'Hrvatski Dragovoljac from Croatia',
#  'Huachipato from Chile',
#  'Huddersfield Town A.F.C. from England',
#  'Huddersfield Town from England',
#  'Hull City from England',
#  'Hungária from Hungary',
#  'Huracán from Argentina',
#  'Hyundai Horangi from South Korea',
#  'Häcken from Sweden',
#  'Hälsingborgs IF from Sweden',
#  'Hércules from Spain',
#  'IF Elfsborg Borås from Sweden',
#  'IF Elfsborg from Sweden',
#  'IFK Eskilstuna from Sweden',
#  'IFK Grängesberg from Sweden',
#  'IFK Göteborg from Sweden',
#  'IFK Norrköping from Sweden',
#  'IK Sirius from Sweden',
#  'IK Sleipner from Sweden',
#  'ILSA Timișoara from Romania',
#  'IR Tanger from Morocco',
#  'IS Halmia from Sweden',
#  'Ibadan from Nigeria',
#  'Iberia Habana from Cuba',
#  'Iberia Havana from Cuba',
#  'Ilhwa Chunma from South Korea',
#  'Imbabura from Ecuador',
#  'Incheon United from South Korea',
#  'Independiente Medellín from Colombia',
#  'Independiente Santa Fe from Colombia',
#  'Independiente de San Vicente from El Salvador',
#  'Independiente del Valle from Ecuador',
#  'Independiente from Argentina',
#  'Inex Toronto from Canada',
#  'Inter Bratislava from Czechoslovakia',
#  'Inter Miami CF from United States',
#  'Inter Milan from Italy',
#  'Interclube from Angola',
#  'Internacional from Brazil',
#  'Internazionale Milan from Italy',
#  'Internazionale Milano F.C. from Italy',
#  'Internazionale from Italy',
#  'Internațional from Romania',
#  'Invercargill Thistle from New Zealand',
#  'Ipswich Town from England',
#  'Iraklis from Greece',
#  'Iskra Žilina from Czechoslovakia',
#  'Istanbulspor from Turkey',
#  'Istres from France',
#  'JE Tizi-Ouzou from Algeria',
#  'JEF United Ichihara from Japan',
#  'JEF United from Japan',
#  'JS El Biar from Algeria',
#  'JS Kairouan from Tunisia',
#  'JS Saint-Pierroise from Réunion',
#  'Jaguares from Mexico',
#  'Jahn Regensburg from Germany',
#  'Jednota Trenčín from Czechoslovakia',
#  'Jeju United from South Korea',
#  'Jeonbuk Hyundai Motors from South Korea',
#  'Jeonnam Dragons from South Korea',
#  'Jomo Cosmos from South Africa',
#  'Jong Ambon Batavia from Dutch East Indies',
#  'Juan Aurich from Peru',
#  'Juventud Asturiana from Cuba',
#  'Juventud Olimpica from El Salvador',
#  'Juventus București from Romania',
#  'Juventus from Italy',
#  'Juárez from Mexico',
#  'Júbilo Iwata from Japan',
#  'KAC Kenitra from Morocco',
#  'KAC Marrakesh from Morocco',
#  'KB from Denmark',
#  'KFC (Kooger FC) from Netherlands',
#  'KSK Liersche from Belgium',
#  'KSV Hessen Kassel from Germany',
#  'KSV Waregem from Belgium',
#  'Kaizer Chiefs from South Africa',
#  'Kansas City Comets from United States',
#  'Kansas City Wizards from United States',
#  'Kapellen from Belgium',
#  'Kapfenberger SV from Austria',
#  'Kardemir Karabükspor from Turkey',
#  'Karlsruher SC from Germany',
#  'Kashima Antlers from Japan',
#  'Kashiwa Reysol from Japan',
#  'Kasımpaşa SK from Turkey',
#  'Kasımpaşa from Turkey',
#  'Kavala from Greece',
#  'Kawasaki Frontale from Japan',
#  'Kayseri Erciyesspor from Turkey',
#  'Kayserispor from Turkey',
#  'Kazma from Kuwait',
#  'Kenitra from Morocco',
#  'Khaitan from Kuwait',
#  'Kharkiv from Ukraine',
#  'Kickers Offenbach from Germany',
#  'Kigwancha from North Korea',
#  'Kilmarnock from Scotland',
#  'King Faisal Babes from Ghana',
#  'Kispest from Hungary',
#  'Kocaelispor from Turkey',
#  'Koninklijke HFC from Netherlands',
#  'Konkuk University from South Korea',
#  'Konyaspor from Turkey',
#  'Koper from Slovenia',
#  'Korea University from South Korea',
#  'Kortrijk from Belgium',
#  'Krasnodar from Russia',
#  'Krylya Sovetov Samara from Russia',
#  'KuPS from Finland',
#  'Kuban Krasnodar from Russia',
#  'Kuwait SC from Kuwait',
#  'Kyonggongop from North Korea',
#  'Kyoto Purple Sanga from Japan',
#  'Kyung Hee University from South Korea',
#  'Křídla vlasti Olomouc from Czechoslovakia',
#  "L'Hospitalet from Spain",
#  'LA Galaxy from United States',
#  'LASK from Austria',
#  'LDU Quito from Ecuador',
#  'LG Cheetahs from South Korea',
#  'La Chaux-de-Fonds from Switzerland',
#  'La Cruz FC from Chile',
#  'La Louviére from Belgium',
#  'La Roche Vendée from France',
#  'La Tour-de-Peilz from Switzerland',
#  'Laguna from Mexico',
#  'Landskrona BoIS from Sweden',
#  'Lanús from Argentina',
#  'Larissa from Greece',
#  'Las Palmas from Spain',
#  'Lausanne Sports from Switzerland',
#  'Lausanne from Switzerland',
#  'Lausanne-Sport from Switzerland',
#  'Laval from France',
#  'Lawn Tennis de la Exposición from Peru',
#  'Lazio from Italy',
#  'Le Havre AC from France',
#  'Le Havre from France',
#  'Le Mans from France',
#  'Lecce from Italy',
#  'Lech Poznań from Poland',
#  'Lechia Gdańsk from Poland',
#  'Leeds United from England',
#  'Leganés from Spain',
#  'Legia Warsaw from Poland',
#  'Leicester City from England',
#  'Leixões from Portugal',
#  'Lekhwiya from Qatar',
#  'Lens from France',
#  'Leones Negros from Mexico',
#  'Levadiakos from Greece',
#  'Levante from Spain',
#  'Levski Sofia from Bulgaria',
#  'Levski-Spartak Sofia from Bulgaria',
#  'León from Mexico',
#  'Liaoning from China',
#  'Libertad from Paraguay',
#  'Liberty Professionals from Ghana',
#  'Liersche Sportkring from Belgium',
#  'Lierse from Belgium',
#  'Lille OSC from France',
#  'Lille from France',
#  'Lillestrøm from Norway',
#  'Limonense from Costa Rica',
#  'Linfield from Northern Ireland',
#  'Linzer ASK from Austria',
#  'Litex Lovech from Bulgaria',
#  'Litoral from Bolivia',
#  'Liverpool F.C. from England',
#  'Liverpool from England',
#  'Liverpool from Uruguay',
#  'Livorno from Italy',
#  'Lobos BUAP from Mexico',
#  'Logroñés from Spain',
#  'Lokeren SNW from Belgium',
#  'Lokeren from Belgium',
#  'Lokomotiv Moscow from Russia',
#  'Lokomotiv Moscow from Soviet Union',
#  'Lokomotiv Plovdiv from Bulgaria',
#  'Lokomotiv Sofia from Bulgaria',
#  'Lokomotiva Košice from Czechoslovakia',
#  'Lokomotiva Zagreb from Yugoslavia',
#  'Lokomotiva from Croatia',
#  'Lokomotíva Košice from Czechoslovakia',
#  'Longa Tilburg from Netherlands',
#  'Lord Cochrane from Chile',
#  'Lorient from France',
#  'Los Angeles FC from United States',
#  'Los Angeles Heat from United States',
#  'Los Angeles Lazers from United States',
#  'Los Angeles Salsa from United States',
#  'Louhans-Cuiseaux from France',
#  'Lucchese from Italy',
#  'Lucerne from Switzerland',
#  'Lucitania Recreation from United States',
#  'Lucky-Goldstar Hwangso from South Korea',
#  'Ludogorets Razgrad from Bulgaria',
#  'Lugano from Switzerland',
#  'Lugo from Spain',
#  'Luton Town from England',
#  'Luzern from Switzerland',
#  'Lyn from Norway',
#  'Lyngby from Denmark',
#  'Lyon from France',
#  'Léon from Mexico',
#  'MA Hussein Dey from Algeria',
#  'MAS Fes from Morocco',
#  'MC Alger from Algeria',
#  'MKE Ankaragücü SK from Turkey',
#  'MP Oran from Algeria',
#  'MSV Duisburg from Germany',
#  'MTK FC from Hungary',
#  'MTK Hungária FC from Hungary',
#  'MTK Hungária from Hungary',
#  'MTK from Hungary',
#  'MVV from Netherlands',
#  'Maccabi București from Romania',
#  'Maccabi Haifa from Israel',
#  'Maccabi Netanya from Israel',
#  'Maccabi Tel Aviv from Israel',
#  'Magallanes from Chile',
#  'Maghreb Fez from Morocco',
#  'Mainz 05 from Germany',
#  'Malavan from Iran',
#  'Mallorca from Spain',
#  'Malmö FF from Sweden',
#  'Malmö from Sweden',
#  'Mamelodi Sundowns from South Africa',
#  'Manchester City from England',
#  'Manchester United F.C. from England',
#  ...]

# %% [markdown]
# 1) 'AEK Athens F.C. from Greece','AEK Athens from Greece',
# 2) Athletic Bilbao from Spain, Atlético Bilbao from Spain,Atlético de Bilbao from Spain Pasar todos a Athletic Bilbao
# 3) Arsenal F.C. from England, Arsenal from England. Pasar a Arsenal F.C.
# 4) 'Atlante F.C. from Mexico', 'Atlante from Mexico'
# 5) 'Austria Vienna from Austria', 'Austria Wien from Austria'
# 6) 'Borussia Dortmund from Germany', 'BV Borussia Dortmund from Germany'
# 7) 'Barcelona SC from Ecuador','Barcelona from Ecuador',
# 8) "Beijing Guo'an from China",'Beijing Guoan from China'
# 9) 'Beşiktaş J.K. from Turkey','Beşiktaş from Turkey',
# 10) 'Blackburn Rovers F.C. from England', 'Blackburn Rovers from England',
# 11) 'Blackpool F.C. from England','Blackpool from England',
# 12) 'Budapest Honvéd FC from Hungary','Budapest Honvéd from Hungary',
# 13) 'Burnley F.C. from England', 'Burnley from England',
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)
# 13)

# %%
cuenta = clubs.groupby(['club_and_origin'])['club_and_origin'].count().to_frame()

# %%
cuenta = cuenta.rename(columns={'club_and_origin': 'count'})

# %%
cuenta.reset_index()

# %%
idf = df.interactive()           # creates an interactive DataFrame with hvPlot

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=1930, end=2022, step=5, value=1930,width=230)

# %%
# Radio buttons for counting fatalities
yAxis = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['national_team','player'],
    button_type='primary'   # choose a color with a predetermined category (as in bootstrap)
    , width=250,height=30
)
#yAxis.servable()

# %%
# Make a pipeline by processing the interactive DataFrame. 
# The slider widget should be incorporated here to separate data by year. 
# That will update the output dynamically(year-by-year).
mPPipeline = (
    idf[
        (idf.year <= year_slider)
    ]
    .groupby("year")[yAxis].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
year_slider

# %%
mPPipeline
